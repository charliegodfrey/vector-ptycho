# %% [markdown]
# # Updating probe and object
# ## Using Mx, My, Mz rather than polar angles and normalising after every iteration.
# ## Now keeping C, A1, A2 fixed.

# %%
import importlib
import vector_ptycho.utils as vpu
importlib.reload(vpu)
from vector_ptycho.utils import *
import numpy as np
import matplotlib.pyplot as plt
import torch
import pickle
from IPython.display import display
from vector_ptycho.utils import _to_numpy

# %%
RGB_scale = make_vector_color_map(plot=False)

# %% [markdown]
# ## Define the object, probe, fluence and XMLD constants

# %%
H, W = 100, 100
Lx = 5
Ly = 5

# Build theta, phi from meron-antimeron generator (returns torch tensors)
theta, phi, Mx, My, Mz = make_meron_antimeron_theta_phi(
    Nx=W,
    Ny=H,
    Lx=Lx,
    Ly=Ly,
    plot=False,
    save_path=None,
    export_path=None,
    return_torch=True,
    out_device=device,
    cm = RGB_scale,
)

# Physical XMLD/Jones constants
C = torch.tensor(50.0+ 5.0j, dtype=cdtype, device=device)
A1 = torch.tensor(1 + 300j, dtype=cdtype, device=device)
A2 = torch.tensor(5 + 2j, dtype=cdtype, device=device)

# Build Jones object from theta, phi
neel = NeelObject(C, A1, A2)
J = neel.build_jones(theta, phi)
obj = JonesObject(J)

# Grid for probe definition
x = torch.linspace(-Lx, Lx, H, device=device)
y = torch.linspace(-Ly, Ly, W, device=device)
X, Y = torch.meshgrid(x, y, indexing='ij')

# Define a probe with some phase structure on the wavefront.
fluence = torch.scalar_tensor(1e6, dtype=torch.float64, device=device)
R=torch.sqrt(X**2+Y**2) #This helps with defining the probe
R_probe = 1.2
Diffuser = 0.1*(torch.sin(1*R)+torch.cos((Y*5+X*1)-0.8*(X-0.2))+torch.cos((Y-X)-0.4*(X)))*(R<R_probe) #(torch.sqrt(3*X**2+1.5*Y**2)+torch.pi/3)#*(torch.exp(-0.1*R)) #np.mod(0.1*(torch.sin(150*R)+torch.cos((Y*10+X*30)**2-0.8*(X*75-0.2))+torch.cos((Y*10-X*33)**2-0.4*(X*50-0.2))),1)
Diffuser = 1.5*R**1.5*(R<R_probe)
P = torch.zeros_like(R)
P = torch.exp(2j*np.pi*Diffuser)*(R<R_probe)#*(torch.exp(-0.8*R))

# Calculate the Jones vectors of the probes for different Linear polarisation states
probes = []
pol_angles = [0, 30, 60, 90]#, 120, 150, 180]
for angle in pol_angles:
    rad = np.deg2rad(angle)
    jones_vec = torch.tensor([np.cos(rad) + 0j, np.sin(rad) + 0j], dtype=cdtype, device=device)
    print(f'Jones vector for {angle} deg linear polarisation: {jones_vec}')
    probes.append(Probe(P, jones_vec, fluence=fluence, normalized=False))

print('Defined {} probes with different linear polarisation states.'.format(len(probes)))


plot_probe_maps(probes[0].amplitude, Lx, Ly)
print('Probe fluence:', probes[0].fluence)
# Out:
# Jones vector for 0 deg linear polarisation: tensor([1.+0.j, 0.+0.j])
# Jones vector for 30 deg linear polarisation: tensor([0.8660+0.j, 0.5000+0.j])
# Jones vector for 60 deg linear polarisation: tensor([0.5000+0.j, 0.8660+0.j])
# Jones vector for 90 deg linear polarisation: tensor([6.1232e-17+0.j, 1.0000e+00+0.j])
# Defined 4 probes with different linear polarisation states.
# Probe fluence: tensor(1000000., dtype=torch.float64)

# %% [markdown]
# # Define the scan trajectory, simulate the detector

# %%
xshiftvec = torch.linspace(-2.5, 2.5,6)
yshiftvec = torch.linspace(-2.5, 2.5,6)

# Shifting the text so that we can plot on the data
dx = (xshiftvec[1] - xshiftvec[0]) / 10
dy = (yshiftvec[1] - yshiftvec[0]) / 10

# Lab-coordinate scan grid used for plotting
xpos_lab, ypos_lab = torch.meshgrid(xshiftvec, yshiftvec, indexing="ij")
positions = torch.stack([ypos_lab.flatten(), xpos_lab.flatten()], dim=1)

# Convert lab coordinates into discrete pixel shifts for torch.roll(row, col)
pixel_size_y = (2 * Ly) / (H - 1)
pixel_size_x = (2 * Lx) / (W - 1)
positions_idx = torch.stack([
    torch.round(positions[:, 0] / pixel_size_y),
    torch.round(positions[:, 1] / pixel_size_x),
], dim=1).to(torch.int64)

scan = ScanTrajectory(positions_idx)

# Forward model
model = ForwardModel(obj, Propagator(), Detector(add_poisson_noise=True))
I_sim = model.simulate_all(probes, scan)
print('Simulated data shape:', I_sim.shape)  # (N_probes, N_positions, H, W)
# Out:
# Simulated data shape: torch.Size([4, 36, 100, 100])

# %%
plot_theta_phi_maps(theta, phi, Lx, Ly,theta_cmap='magma',
                       phi_cmap=RGB_scale,
                       positions=positions, dx=0.3, dy=0.3, show_positions=True, label_positions=True, label_axes=True)
# Out:
# (<Figure size 1200x500 with 4 Axes>,
#  array([<Axes: title={'center': '$l_z$ heatmap'}, xlabel='$x$ [m]', ylabel='$y$ [m]'>,
#         <Axes: title={'center': '$\\phi$ heatmap'}, xlabel='$x$ [m]', ylabel='$y$ [m]'>],
#        dtype=object))

# %%
# Normalise I_sim for the autograd - divide by the mean to keep values around 1, which helps with the gradients - now l has a magnitude of 1, probe and detector have values around 1, so the gradients are nicely balanced and we don't have to worry about vanishing or exploding gradients as much.
I_sim_norm = I_sim / I_sim.mean()

# %%
def plot_some_diffraction_patterns(I_sim, positions, scan_indices):
    fig, axes = plt.subplots(4, 4, figsize=(12, 12))

    #scan_indices = [35, 36, 45, 43]
    scan_indices = [1, 2, 20, 24]
    probe_numbers = [0, 1, 2, 3]

    for i, probe_number in enumerate(probe_numbers):      # rows
        for j, scan_idx in enumerate(scan_indices):       # columns
            
            axes[i, j].imshow(
                ((I_sim[probe_number, scan_idx].cpu()+1e-8)),
                cmap='inferno'
            )
            
            '''
            axes[i, j].imshow(
                np.log10(I_sim[probe_number, scan_idx].cpu()+1e-8),
                cmap='inferno',
            )
            '''
            axes[i, j].set_title(f'Probe {probe_number}, Pos {scan_idx}, x={positions[scan_idx, 0].item():.2f}, y={positions[scan_idx, 1].item():.2f}')
            axes[i, j].axis('off')

    plt.tight_layout()
    plt.show()

plot_some_diffraction_patterns(I_sim, positions, scan_indices)

# %%
def normalise_neel(l):
    # Normalize to ensure L is always a unit vector
    mag = torch.sqrt(torch.sum(l**2, dim=0) + 1e-8)
    Lx = l[0] / mag
    Ly = l[1] / mag
    Lz = l[2] / mag
    return Lx, Ly, Lz

def optimize_object(scan, pol_angles, I_meas, H, W, initial_l, initial_probe_amplitude,num_iterations=100, device=None,
                                             optimizer_params={'l_lr': 1e-1, 'CA_lr': 1e-5},
                                             plot_filename=None):
    """
    Reconstruct probes (different for each polarisation) l C, A1, A2 from measured diffraction patterns.
    This is different to previous versions because it directly updates lx, ly, lz to avoid differentiation problems associated with angular coordinates.
    .
    Parameters
    ----------
    scan : ScanTrajectory
        Scan positions.
    pol_angles : list of float
        List of polarisation angles in degrees for each probe.
    I_meas : torch.Tensor
        Measured diffraction intensities, shape (N_probes, N_scan, Hdet, Wdet)
    H, W : int
        Object map size.
    initial_l : torch.Tensor
        Initial guess for the neel vector in Cartesian coordinates, shape (3, H, W).
    initial_probe_amplitude : torch.Tensor
        Initial guess for the probe amplitude, shape (H, W).
    num_iterations : int
        Number of optimization steps.
    device : torch.device or str
        Device to use.
    loss_prefactors : dict
        Prefactors for different loss components - how much to weight anisotropy and gradient losses relative to the amplitude loss.
    optimizer_params : dict
        Learning rates for different parameter groups in the optimizer.
    plot_filename : str or None
        If not None, save intermediate plots to this filename during optimization.
     Returns
    -------
    dict
        Reconstructed parameters and loss history.
    """
    if device is None:
        device = I_meas.device

    # This is for the live plot updates
    plot_update = create_live_plotter(Lx, Ly, phi_cmap=RGB_scale, theta_cmap='magma')

    eps = 1e-12
    cdtype = torch.complex64

    # Learnable parameters

    l = torch.nn.Parameter(initial_l) # Defining the neel vector in terms of it's lx, ly, lz components, which are then normalised to get theta and phi. This is easier to optimise than directly optimising theta and phi, which have singularities at the poles.
    probe_amplitude = initial_probe_amplitude

    # Initialise the probe array (same for all pol states at the moment)
    probes = []
    for angle in pol_angles:
        rad = np.deg2rad(angle)
        jones_vec = torch.tensor([np.cos(rad) + 0j, np.sin(rad) + 0j], dtype=cdtype, device=device)
        probes.append(Probe(probe_amplitude, jones_vec, fluence=fluence, normalized=False))
    probe_amplitude = (probes[0].amplitude) #It has now been normalised to the correct fluence.
    probe_amplitude_start = probes[0].amplitude
    fluence_calc = torch.sum(torch.abs(probe_amplitude_start)**2)
    print(f"Calculated initial fluence from probe amplitude: {fluence_calc.item():.6e}, target fluence: {fluence.item():.6e}")

    optimizer = torch.optim.AdamW([
        {"params": [l], "lr": optimizer_params['l_lr']},
        {"params": [C, A1, A2], "lr": optimizer_params['CA_lr']}
        ])
    
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer,
        mode='min',
        factor=0.5,       # reduce LR by 2x
        patience=5,      # wait 5 iterations without improvement
        threshold=1e-3,   # minimum change to count as improvement
        min_lr=1e-6,      # don't go too small
    )
    loss_history = []

    for iteration in range(num_iterations):
        optimizer.zero_grad(set_to_none=True)

        l_mag = torch.sqrt(torch.sum(l**2, dim=0) + 1e-8) 
        
        # Create normalized Cartesian components
        lx_norm = l[0] / l_mag
        ly_norm = l[1] / l_mag
        lz_norm = l[2] / l_mag

        # Build Jones object from current parameters
        neel = NeelObject(C, A1, A2)
        J = neel.build_jones_from_cartesian(lx= lx_norm, ly=ly_norm, lz=lz_norm)
        obj = JonesObject(J)

        # Remake the probe array
        probes = []
        for angle in pol_angles:
            rad = np.deg2rad(angle)
            jones_vec = torch.tensor([np.cos(rad) + 0j, np.sin(rad) + 0j], dtype=cdtype, device=device)
            probes.append(Probe(probe_amplitude, jones_vec, fluence=fluence, normalized=True))

        # Forward model
        model = ForwardModel(obj, Propagator(), Detector())
        I_pred = model.simulate_all(probes, scan)
        eps = 1e-8

        fluence_calc = torch.sum(torch.abs(probe_amplitude)**2)
        print(f"Calculated fluence from probe amplitude: {fluence_calc.item():.6e}, target fluence: {fluence.item():.6e}")

        # Define the loss function
        loss = torch.mean((torch.sqrt(I_pred + eps) - torch.sqrt(I_meas + eps))**2)

        loss.backward()
        optimizer.step()

        # Step the scheduler with the current loss
        scheduler.step(loss)

        if iteration % 20 == 0:
            print([group['lr'] for group in optimizer.param_groups])

        loss_history.append(loss.item())

        if iteration % 1 == 0:
            theta = torch.acos(lz_norm)
            phi = torch.atan2(ly_norm, lx_norm)
            l_mag = torch.sqrt(torch.sum(l**2, dim=0) + 1e-8)
            print(f"Iter {iteration:4d} | Loss = {loss.item():.6e}")
            plot_update(probe_amplitude, theta, phi, loss, save_filename=plot_filename)

    return {
        "l": l.detach(),
        "probe_amplitude": probe_amplitude.detach(),
        "C": C.detach(),
        "A1": A1.detach(),
        "A2": A2.detach(),
        "loss_history": loss_history,
        "optimizer_params": optimizer_params  
    }

'''
initial_l = torch.stack([
    torch.randn(H, W, device=device)*0.1,
    torch.randn(H, W, device=device)*1,
    torch.randn(H, W, device=device)*0.1
])
'''
initial_l = torch.randn(3, H, W, device=device)
result = optimize_object(scan, pol_angles, I_sim, H, W,
                                initial_probe_amplitude=P,
                                initial_l=initial_l,
                                num_iterations=5, device=device)
# Out:
# Calculated initial fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# [0.1, 1e-05]
# Iter    0 | Loss = 1.705631e+02
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter    1 | Loss = 1.450125e+02
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter    2 | Loss = 1.217060e+02
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter    3 | Loss = 1.016911e+02
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter    4 | Loss = 8.497025e+01

# %%
def normalise_neel(l):
    # Normalize to ensure L is always a unit vector
    mag = torch.sqrt(torch.sum(l**2, dim=0) + 1e-8)
    Lx = l[0] / mag
    Ly = l[1] / mag
    Lz = l[2] / mag
    return Lx, Ly, Lz

def optimize_object_and_probe_with_scheduler(scan, pol_angles, I_meas, H, W, initial_l, initial_probe_amplitude,num_iterations=100, device=None, 
                                             loss_prefactors={'sqrt_amp_pf': 1.0, 'gradient_pf': 1e-4, 'anisotropy_pf': 1e-4, 'probe_localisation_pf': 1e-3},
                                             optimizer_params={'l_lr': 1e-3, 'CA_lr': 1e-5, 'probe_lr': 60e-1},
                                             plot_filename=None, object_randomisation=False, probe_randomisation=False):
    """
    Reconstruct probes (different for each polarisation) l C, A1, A2 from measured diffraction patterns.
    This is different to previous versions because it directly updates lx, ly, lz to avoid differentiation problems associated with angular coordinates.
    .
    Parameters
    ----------
    scan : ScanTrajectory
        Scan positions.
    pol_angles : list of float
        List of polarisation angles in degrees for each probe.
    I_meas : torch.Tensor
        Measured diffraction intensities, shape (N_probes, N_scan, Hdet, Wdet)
    H, W : int
        Object map size.
    initial_l : torch.Tensor
        Initial guess for the neel vector in Cartesian coordinates, shape (3, H, W).
    initial_probe_amplitude : torch.Tensor
        Initial guess for the probe amplitude, shape (H, W).
    num_iterations : int
        Number of optimization steps.
    device : torch.device or str
        Device to use.
    loss_prefactors : dict
        Prefactors for different loss components - how much to weight anisotropy and gradient losses relative to the amplitude loss.
    optimizer_params : dict
        Learning rates for different parameter groups in the optimizer.
    plot_filename : str or None
        If not None, save intermediate plots to this filename during optimization.
    object_randomisation : bool
        Whether to apply randomisation to the object parameters during optimization to help escape local minima.
    probe_randomisation : bool
        Whether to apply randomisation to the probe parameters during optimization to help escape local minima.
     Returns
    -------
    dict
        Reconstructed parameters and loss history.
    """
    if device is None:
        device = I_meas.device

    # This is for the live plot updates
    plot_update = create_live_plotter(Lx, Ly, phi_cmap=RGB_scale, theta_cmap='magma')

    eps = 1e-6
    cdtype = torch.complex64

    # Learnable parameters

    l = torch.nn.Parameter(initial_l) # Defining the neel vector in terms of it's lx, ly, lz components, which are then normalised to get theta and phi. This is easier to optimise than directly optimising theta and phi, which have singularities at the poles.
    probe_amplitude = initial_probe_amplitude

    # Initialise the probe array (same for all pol states at the moment)
    probes = []
    for angle in pol_angles:
        rad = np.deg2rad(angle)
        jones_vec = torch.tensor([np.cos(rad) + 0j, np.sin(rad) + 0j], dtype=cdtype, device=device)
        probes.append(Probe(probe_amplitude, jones_vec, fluence=fluence, normalized=False))
    probe_amplitude = torch.nn.Parameter(probes[0].amplitude) #It has now been normalised to the correct fluence.
    probe_amplitude_start = probes[0].amplitude
    fluence_calc = torch.sum(torch.abs(probe_amplitude_start)**2)
    print(f"Calculated initial fluence from probe amplitude: {fluence_calc.item():.6e}, target fluence: {fluence.item():.6e}")

    optimizer = torch.optim.AdamW([
        {"params": [l], "lr": optimizer_params['l_lr']}, #{"params": [C, A1, A2], "lr": optimizer_params['CA_lr']},
        {"params": [probe_amplitude], "lr": optimizer_params['probe_lr']}
        ])
    
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer,
        mode='min',
        factor=0.5,       # reduce LR by 2x
        patience=500,      # wait 5 iterations without improvement
        threshold=1e-3,   # minimum change to count as improvement
        min_lr=1e-6,      # don't go too small
    )
    loss_history = []

    for iteration in range(num_iterations):
        STXM_end_iteration = 50
        if iteration < STXM_end_iteration:
            for p in [l, C, A1, A2]:
                p.requires_grad_(True)
            probe_amplitude.requires_grad_(False)
            loss_prefactors['STXM_pf_c'] = loss_prefactors['STXM_pf']#/((iteration+1)/STXM_end_iteration)
            loss_prefactors['sqrt_amp_pf_c'] = loss_prefactors['sqrt_amp_pf']#*(iteration+1)/STXM_end_iteration
            print('Free object parameters, fixing probe amplitude.')
        '''
        if iteration >= STXM_end_iteration and iteration < 70:
            for p in [l, C, A1, A2]:
                p.requires_grad_(False)
            probe_amplitude.requires_grad_(True)
            loss_prefactors['sqrt_amp_pf_c'] = 1.0
            loss_prefactors['STXM_pf_c'] = 0.0
            print('Free probe, fixed object')
        '''
        if iteration >= 50 and iteration % 2 == 0:
            for p in [l, C, A1, A2]:
                p.requires_grad_(True)
            probe_amplitude.requires_grad_(False)
        if iteration >= 50 and iteration % 2 == 1:
            for p in [l, C, A1, A2]:
                p.requires_grad_(False)
            probe_amplitude.requires_grad_(True)
        if iteration >= 80:
            for p in [l, C, A1, A2]:
                p.requires_grad_(True)
            probe_amplitude.requires_grad_(True)
            print('Freeing all parameters.')
        
        optimizer.zero_grad(set_to_none=True)

        l_mag = torch.sqrt(torch.sum(l**2, dim=0) + 1e-8) 
        
        # Create normalized Cartesian components
        lx_norm = l[0] / l_mag
        ly_norm = l[1] / l_mag
        lz_norm = l[2] / l_mag

        # Build Jones object from current parameters
        neel = NeelObject(C, A1, A2)
        J = neel.build_jones_from_cartesian(lx= lx_norm, ly=ly_norm, lz=lz_norm)
        obj = JonesObject(J)

        # Remake the probe array
        probes = []
        for angle in pol_angles:
            rad = np.deg2rad(angle)
            jones_vec = torch.tensor([np.cos(rad) + 0j, np.sin(rad) + 0j], dtype=cdtype, device=device)
            probes.append(Probe(probe_amplitude, jones_vec, fluence=fluence, normalized=True))

        # Forward model
        model = ForwardModel(obj, Propagator(), Detector())
        I_pred = model.simulate_all(probes, scan)
        I_pred_safe = torch.clamp(I_pred, min=0.0)
        

        fluence_calc = torch.sum(torch.abs(probe_amplitude)**2)
        print(f"Calculated fluence from probe amplitude: {fluence_calc.item():.6e}, target fluence: {fluence.item():.6e}")
        '''
        if loss_prefactors['gradient_pf'] > 0 or loss_prefactors['anisotropy_pf'] > 0:
            #Only perform this computation if the prefactors are > 0, as it is quite expensive.

            # 2. Compute spatial gradients using finite differences
            # Differences along the X-axis (width)
            dx_lx = torch.diff(lx_norm, dim=-1)
            dx_ly = torch.diff(ly_norm, dim=-1)
            dx_lz = torch.diff(lz_norm, dim=-1)

            # Differences along the Y-axis (height)
            dy_lx = torch.diff(lx_norm, dim=-2)
            dy_ly = torch.diff(ly_norm, dim=-2)
            dy_lz = torch.diff(lz_norm, dim=-2)

            grad_mag_x = torch.sqrt(dx_lx**2 + dx_ly**2 + dx_lz**2 + 1e-8) # 1e-8 prevents NaN in sqrt at 0
            grad_mag_y = torch.sqrt(dy_lx**2 + dy_ly**2 + dy_lz**2 + 1e-8)

            loss_x = torch.sum(grad_mag_x**2)
            loss_y = torch.sum(grad_mag_y**2)

            gradient_loss = loss_x + loss_y
            anisotropy_loss = torch.sum(l[2]**2) # Positive prefactor will favour IP alignment.
        else:
            gradient_loss = 0.0
            anisotropy_loss = 0.0
        '''
        '''
        # Amplitude-based ptychographic loss
        if loss_prefactors['probe_localisation_pf'] > 0:
            probe_localisation_loss = loss_prefactors['probe_localisation_pf'] * torch.mean(torch.abs(probe_amplitude)**2*R**2) #This stops the probe from drifting by penalising amplitude at large R
        else:
            probe_localisation_loss = 0.0
        '''
        # Define the loss function
        loss = loss_prefactors['sqrt_amp_pf_c'] * torch.mean((torch.sqrt(I_pred_safe + eps) - torch.sqrt(I_meas + eps))**2) #+ loss_prefactors['gradient_pf'] * gradient_loss + loss_prefactors['anisotropy_pf'] * anisotropy_loss + probe_localisation_loss
        #loss = loss + loss_prefactors['STXM_pf']*(torch.sqrt(torch.sum(I_pred_safe + eps) - torch.sqrt(torch.sum(I_meas + eps)))**2) # This is a simple loss term to try to match the total intensity, which can help with convergence when the probe is also being optimised.
        # Loop over each diffraction pattern and measure the difference in the total intensity transmitted
        for pos in range(len(scan.positions)):
            for pol in range(len(pol_angles)):
                loss = loss+loss_prefactors['STXM_pf_c']*(torch.sqrt(torch.sum(I_pred_safe[pol, pos, :,:] + eps)) - torch.sqrt(torch.sum(I_meas[pol, pos, :,:] + eps)))**2
        
        loss = loss + loss_prefactors['probe_size_pf'] * torch.sum(torch.abs(probe_amplitude)*(R>R_probe))
        loss.backward()
        optimizer.step()

        # Step the scheduler with the current loss
        scheduler.step(loss)

        if iteration % 20 == 0:
            print([group['lr'] for group in optimizer.param_groups])
        
        if iteration % 8 == 0 and iteration < 30:
            with torch.no_grad():
                if probe_randomisation:
                    probe_amplitude.data += (torch.rand((H, W), device=device) * torch.max(torch.abs(probe_amplitude))*0.25)
                if object_randomisation:
                    for i in range(3):
                        noise = torch.randn_like(l[i])
                        l[i] += 1.5 * noise

        loss_history.append(loss.item())

        if iteration % 1 == 0:
            theta = torch.acos(torch.clamp(lz_norm, -1.0 + 1e-6, 1.0 - 1e-6)) # Clamp to avoid NaNs from acos outside of [-1, 1]
            phi = torch.atan2(ly_norm, lx_norm)
            l_mag = torch.sqrt(torch.sum(l**2, dim=0) + eps)
            print(f"Iter {iteration:4d} | Loss = {loss.item():.6e} | C, A1, A2: {C.item():.6e}, {A1.item():.6e}, {A2.item():.6e}")
            plot_update(probe_amplitude, theta, phi, loss, save_filename=plot_filename)

    return {
        "l": l.detach(),
        "probe_amplitude": probe_amplitude.detach(),
        "C": C.detach(),
        "A1": A1.detach(),
        "A2": A2.detach(),
        "loss_history": loss_history,
        "optimizer_params": optimizer_params,
        "loss_prefactors": loss_prefactors,   
    }

# %%
#initial_l = torch.randn(3, H, W, device=device)

initial_l = torch.stack([
    torch.randn(H, W, device=device)*0.1,
    torch.randn(H, W, device=device)*1,
    torch.randn(H, W, device=device)*0.1
])

#Diffuser = 0.1*(torch.sin(1*R)+torch.cos((Y*5+X*1)-0.8*(X-0.2))+torch.cos((Y-X)-0.4*(X)))*(R<R_probe) #(torch.sqrt(3*X**2+1.5*Y**2)+torch.pi/3)#*(torch.exp(-0.1*R)) #np.mod(0.1*(torch.sin(150*R)+torch.cos((Y*10+X*30)**2-0.8*(X*75-0.2))+torch.cos((Y*10-X*33)**2-0.4*(X*50-0.2))),1)
Diffuser = torch.zeros_like(R)
#Diffuser = torch.randn_like(R)*(R<R_probe)
P_test = torch.zeros_like(R)
P_test = torch.exp(2j*np.pi*Diffuser)*(torch.exp(-0.8*R))
initial_probe_amplitude = P_test


def normalise_probe_from_data(I_meas_normalized, initial_probe_amplitude):
    # 1. Average the data and take the square root
    I_avg = torch.mean(I_meas_normalized, dim=(0, 1)) # Average over pol states and scan positions

    I_w_initial_p = (torch.abs(F(initial_probe_amplitude))**2)
    scaler = torch.sqrt(torch.sum(I_avg) / (torch.sum(I_w_initial_p) + 1e-8))
    print('Probe scaler:', scaler)
    return initial_probe_amplitude*scaler

#initial_probe_amplitude = normalise_probe_from_data(I_sim_norm, initial_probe_amplitude)
#print('Max of detector with initial probe:', torch.max(torch.abs(F(initial_probe_amplitude))**2))
#print('Max of normalized detector data:', torch.max(I_sim_norm))

optimizer_params={'l_lr': 1e-1, 'CA_lr': 1e-5, 'probe_lr':1e-1}

# These are the initial loss prefactors which may change over the course of the iterations.
loss_prefactors={'sqrt_amp_pf': 1.0, 'gradient_pf': 0.0, 
                 'anisotropy_pf': 0.0, 'probe_localisation_pf':0.0,
                 'STXM_pf': 1.0,
                 'probe_size_pf': 1e-2} # Different parts of the Loss have different weights

'''Randomisation can help a minimum be found - this section tells what gets randomised, by how much and when it stops taking effect'''
object_randomisation = False # Randomise the object at the start of the optimization to help escape local minima
probe_randomisation = False # Randomise the probe at the start of the optimization to help escape local minima
randomisation_dict = {'object_randomisation': object_randomisation, 'probe_randomisation': probe_randomisation,
                      'object_rand_pf': 0.15, 'probe_rand_pf': 0.1, 'iter_spacing': 5, 'final_iteration': 50}

result = optimize_object_and_probe_with_scheduler(scan, pol_angles, I_sim, H, W,
                                   initial_probe_amplitude=initial_probe_amplitude,
                                   initial_l=initial_l,
                                   num_iterations=1000, device=device,
                                   loss_prefactors=loss_prefactors, object_randomisation=object_randomisation,
                                   probe_randomisation=probe_randomisation, optimizer_params=optimizer_params)
# Out:
# Calculated initial fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# [0.1, 0.1]
# Iter    0 | Loss = 1.909782e+08 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter    1 | Loss = 1.075730e+08 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter    2 | Loss = 6.320864e+07 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter    3 | Loss = 4.126578e+07 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter    4 | Loss = 3.074249e+07 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter    5 | Loss = 2.536436e+07 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter    6 | Loss = 2.206765e+07 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter    7 | Loss = 1.953321e+07 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter    8 | Loss = 1.732352e+07 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter    9 | Loss = 1.535632e+07 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter   10 | Loss = 1.364801e+07 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter   11 | Loss = 1.221305e+07 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter   12 | Loss = 1.103979e+07 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter   13 | Loss = 1.009510e+07 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter   14 | Loss = 9.335957e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter   15 | Loss = 8.719513e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter   16 | Loss = 8.208795e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter   17 | Loss = 7.774737e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter   18 | Loss = 7.395923e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter   19 | Loss = 7.057279e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# [0.1, 0.1]
# Iter   20 | Loss = 6.748610e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter   21 | Loss = 6.463302e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter   22 | Loss = 6.197376e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter   23 | Loss = 5.948732e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter   24 | Loss = 5.716526e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter   25 | Loss = 5.500575e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter   26 | Loss = 5.300905e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter   27 | Loss = 5.117418e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter   28 | Loss = 4.949705e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter   29 | Loss = 4.797042e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter   30 | Loss = 4.658390e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter   31 | Loss = 4.532523e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter   32 | Loss = 4.418118e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter   33 | Loss = 4.313844e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter   34 | Loss = 4.218450e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter   35 | Loss = 4.130809e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter   36 | Loss = 4.049943e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter   37 | Loss = 3.975038e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter   38 | Loss = 3.905418e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter   39 | Loss = 3.840537e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# [0.1, 0.1]
# Iter   40 | Loss = 3.779940e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter   41 | Loss = 3.723240e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter   42 | Loss = 3.670119e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter   43 | Loss = 3.620288e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter   44 | Loss = 3.573513e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter   45 | Loss = 3.529586e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter   46 | Loss = 3.488341e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter   47 | Loss = 3.449631e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter   48 | Loss = 3.413332e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter   49 | Loss = 3.379324e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter   50 | Loss = 3.347485e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 9.999999e+05, target fluence: 1.000000e+06
# Iter   51 | Loss = 3.317692e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.000584e+06, target fluence: 1.000000e+06
# Iter   52 | Loss = 3.242008e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.000584e+06, target fluence: 1.000000e+06
# Iter   53 | Loss = 3.214444e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.001286e+06, target fluence: 1.000000e+06
# Iter   54 | Loss = 3.140113e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.001286e+06, target fluence: 1.000000e+06
# Iter   55 | Loss = 3.114584e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.002255e+06, target fluence: 1.000000e+06
# Iter   56 | Loss = 3.042093e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.002255e+06, target fluence: 1.000000e+06
# Iter   57 | Loss = 3.018353e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.003388e+06, target fluence: 1.000000e+06
# Iter   58 | Loss = 2.947642e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.003388e+06, target fluence: 1.000000e+06
# Iter   59 | Loss = 2.925432e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.004588e+06, target fluence: 1.000000e+06
# [0.1, 0.1]
# Iter   60 | Loss = 2.856449e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.004588e+06, target fluence: 1.000000e+06
# Iter   61 | Loss = 2.835506e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.005810e+06, target fluence: 1.000000e+06
# Iter   62 | Loss = 2.768348e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.005810e+06, target fluence: 1.000000e+06
# Iter   63 | Loss = 2.748426e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.007005e+06, target fluence: 1.000000e+06
# Iter   64 | Loss = 2.683138e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.007005e+06, target fluence: 1.000000e+06
# Iter   65 | Loss = 2.664029e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.008121e+06, target fluence: 1.000000e+06
# Iter   66 | Loss = 2.600540e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.008121e+06, target fluence: 1.000000e+06
# Iter   67 | Loss = 2.582094e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.009119e+06, target fluence: 1.000000e+06
# Iter   68 | Loss = 2.520258e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.009119e+06, target fluence: 1.000000e+06
# Iter   69 | Loss = 2.502389e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.009994e+06, target fluence: 1.000000e+06
# Iter   70 | Loss = 2.442083e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.009994e+06, target fluence: 1.000000e+06
# Iter   71 | Loss = 2.424770e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.010779e+06, target fluence: 1.000000e+06
# Iter   72 | Loss = 2.365944e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.010779e+06, target fluence: 1.000000e+06
# Iter   73 | Loss = 2.349202e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.011518e+06, target fluence: 1.000000e+06
# Iter   74 | Loss = 2.291830e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.011518e+06, target fluence: 1.000000e+06
# Iter   75 | Loss = 2.275704e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.012257e+06, target fluence: 1.000000e+06
# Iter   76 | Loss = 2.219754e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.012257e+06, target fluence: 1.000000e+06
# Iter   77 | Loss = 2.204280e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.013028e+06, target fluence: 1.000000e+06
# Iter   78 | Loss = 2.149702e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.013028e+06, target fluence: 1.000000e+06
# Iter   79 | Loss = 2.134916e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.013853e+06, target fluence: 1.000000e+06
# [0.1, 0.1]
# Iter   80 | Loss = 2.081665e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.014684e+06, target fluence: 1.000000e+06
# Iter   81 | Loss = 2.015650e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.015530e+06, target fluence: 1.000000e+06
# Iter   82 | Loss = 1.951642e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.016395e+06, target fluence: 1.000000e+06
# Iter   83 | Loss = 1.889616e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.017270e+06, target fluence: 1.000000e+06
# Iter   84 | Loss = 1.829530e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.018138e+06, target fluence: 1.000000e+06
# Iter   85 | Loss = 1.771335e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.018981e+06, target fluence: 1.000000e+06
# Iter   86 | Loss = 1.714968e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.019780e+06, target fluence: 1.000000e+06
# Iter   87 | Loss = 1.660371e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.020526e+06, target fluence: 1.000000e+06
# Iter   88 | Loss = 1.607488e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.021215e+06, target fluence: 1.000000e+06
# Iter   89 | Loss = 1.556268e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.021849e+06, target fluence: 1.000000e+06
# Iter   90 | Loss = 1.506659e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.022437e+06, target fluence: 1.000000e+06
# Iter   91 | Loss = 1.458617e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.022990e+06, target fluence: 1.000000e+06
# Iter   92 | Loss = 1.412101e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.023517e+06, target fluence: 1.000000e+06
# Iter   93 | Loss = 1.367076e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.024027e+06, target fluence: 1.000000e+06
# Iter   94 | Loss = 1.323511e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.024525e+06, target fluence: 1.000000e+06
# Iter   95 | Loss = 1.281376e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.025013e+06, target fluence: 1.000000e+06
# Iter   96 | Loss = 1.240645e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.025491e+06, target fluence: 1.000000e+06
# Iter   97 | Loss = 1.201287e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.025957e+06, target fluence: 1.000000e+06
# Iter   98 | Loss = 1.163268e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.026409e+06, target fluence: 1.000000e+06
# Iter   99 | Loss = 1.126553e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.026846e+06, target fluence: 1.000000e+06
# [0.1, 0.1]
# Iter  100 | Loss = 1.091103e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.027268e+06, target fluence: 1.000000e+06
# Iter  101 | Loss = 1.056878e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.027680e+06, target fluence: 1.000000e+06
# Iter  102 | Loss = 1.023837e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.028085e+06, target fluence: 1.000000e+06
# Iter  103 | Loss = 9.919387e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.028487e+06, target fluence: 1.000000e+06
# Iter  104 | Loss = 9.611444e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.028891e+06, target fluence: 1.000000e+06
# Iter  105 | Loss = 9.314142e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.029301e+06, target fluence: 1.000000e+06
# Iter  106 | Loss = 9.027114e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.029716e+06, target fluence: 1.000000e+06
# Iter  107 | Loss = 8.750009e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.030138e+06, target fluence: 1.000000e+06
# Iter  108 | Loss = 8.482484e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.030562e+06, target fluence: 1.000000e+06
# Iter  109 | Loss = 8.224216e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.030986e+06, target fluence: 1.000000e+06
# Iter  110 | Loss = 7.974881e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.031404e+06, target fluence: 1.000000e+06
# Iter  111 | Loss = 7.734178e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.031811e+06, target fluence: 1.000000e+06
# Iter  112 | Loss = 7.501804e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.032204e+06, target fluence: 1.000000e+06
# Iter  113 | Loss = 7.277462e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.032578e+06, target fluence: 1.000000e+06
# Iter  114 | Loss = 7.060850e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.032931e+06, target fluence: 1.000000e+06
# Iter  115 | Loss = 6.851681e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.033262e+06, target fluence: 1.000000e+06
# Iter  116 | Loss = 6.649661e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.033572e+06, target fluence: 1.000000e+06
# Iter  117 | Loss = 6.454505e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.033861e+06, target fluence: 1.000000e+06
# Iter  118 | Loss = 6.265925e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.034130e+06, target fluence: 1.000000e+06
# Iter  119 | Loss = 6.083663e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.034380e+06, target fluence: 1.000000e+06
# [0.1, 0.1]
# Iter  120 | Loss = 5.907438e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.034613e+06, target fluence: 1.000000e+06
# Iter  121 | Loss = 5.736999e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.034828e+06, target fluence: 1.000000e+06
# Iter  122 | Loss = 5.572111e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.035028e+06, target fluence: 1.000000e+06
# Iter  123 | Loss = 5.412552e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.035213e+06, target fluence: 1.000000e+06
# Iter  124 | Loss = 5.258109e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.035383e+06, target fluence: 1.000000e+06
# Iter  125 | Loss = 5.108587e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.035540e+06, target fluence: 1.000000e+06
# Iter  126 | Loss = 4.963796e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.035685e+06, target fluence: 1.000000e+06
# Iter  127 | Loss = 4.823548e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.035820e+06, target fluence: 1.000000e+06
# Iter  128 | Loss = 4.687664e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.035946e+06, target fluence: 1.000000e+06
# Iter  129 | Loss = 4.555974e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.036067e+06, target fluence: 1.000000e+06
# Iter  130 | Loss = 4.428294e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.036184e+06, target fluence: 1.000000e+06
# Iter  131 | Loss = 4.304465e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.036297e+06, target fluence: 1.000000e+06
# Iter  132 | Loss = 4.184331e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.036409e+06, target fluence: 1.000000e+06
# Iter  133 | Loss = 4.067741e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.036520e+06, target fluence: 1.000000e+06
# Iter  134 | Loss = 3.954556e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.036630e+06, target fluence: 1.000000e+06
# Iter  135 | Loss = 3.844649e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.036738e+06, target fluence: 1.000000e+06
# Iter  136 | Loss = 3.737900e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.036846e+06, target fluence: 1.000000e+06
# Iter  137 | Loss = 3.634198e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.036951e+06, target fluence: 1.000000e+06
# Iter  138 | Loss = 3.533438e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.037054e+06, target fluence: 1.000000e+06
# Iter  139 | Loss = 3.435514e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.037154e+06, target fluence: 1.000000e+06
# [0.1, 0.1]
# Iter  140 | Loss = 3.340332e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.037252e+06, target fluence: 1.000000e+06
# Iter  141 | Loss = 3.247808e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.037348e+06, target fluence: 1.000000e+06
# Iter  142 | Loss = 3.157854e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.037441e+06, target fluence: 1.000000e+06
# Iter  143 | Loss = 3.070400e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.037533e+06, target fluence: 1.000000e+06
# Iter  144 | Loss = 2.985372e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.037622e+06, target fluence: 1.000000e+06
# Iter  145 | Loss = 2.902710e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.037710e+06, target fluence: 1.000000e+06
# Iter  146 | Loss = 2.822361e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.037796e+06, target fluence: 1.000000e+06
# Iter  147 | Loss = 2.744269e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.037880e+06, target fluence: 1.000000e+06
# Iter  148 | Loss = 2.668384e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.037960e+06, target fluence: 1.000000e+06
# Iter  149 | Loss = 2.594656e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.038039e+06, target fluence: 1.000000e+06
# Iter  150 | Loss = 2.523036e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.038114e+06, target fluence: 1.000000e+06
# Iter  151 | Loss = 2.453474e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.038187e+06, target fluence: 1.000000e+06
# Iter  152 | Loss = 2.385928e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.038258e+06, target fluence: 1.000000e+06
# Iter  153 | Loss = 2.320347e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.038327e+06, target fluence: 1.000000e+06
# Iter  154 | Loss = 2.256690e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.038395e+06, target fluence: 1.000000e+06
# Iter  155 | Loss = 2.194903e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.038462e+06, target fluence: 1.000000e+06
# Iter  156 | Loss = 2.134947e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.038529e+06, target fluence: 1.000000e+06
# Iter  157 | Loss = 2.076771e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.038596e+06, target fluence: 1.000000e+06
# Iter  158 | Loss = 2.020335e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.038663e+06, target fluence: 1.000000e+06
# Iter  159 | Loss = 1.965595e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.038730e+06, target fluence: 1.000000e+06
# [0.1, 0.1]
# Iter  160 | Loss = 1.912508e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.038796e+06, target fluence: 1.000000e+06
# Iter  161 | Loss = 1.861035e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.038863e+06, target fluence: 1.000000e+06
# Iter  162 | Loss = 1.811136e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.038928e+06, target fluence: 1.000000e+06
# Iter  163 | Loss = 1.762762e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.038994e+06, target fluence: 1.000000e+06
# Iter  164 | Loss = 1.715878e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.039059e+06, target fluence: 1.000000e+06
# Iter  165 | Loss = 1.670440e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.039124e+06, target fluence: 1.000000e+06
# Iter  166 | Loss = 1.626400e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.039189e+06, target fluence: 1.000000e+06
# Iter  167 | Loss = 1.583719e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.039255e+06, target fluence: 1.000000e+06
# Iter  168 | Loss = 1.542352e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.039321e+06, target fluence: 1.000000e+06
# Iter  169 | Loss = 1.502252e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.039388e+06, target fluence: 1.000000e+06
# Iter  170 | Loss = 1.463381e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.039456e+06, target fluence: 1.000000e+06
# Iter  171 | Loss = 1.425702e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.039523e+06, target fluence: 1.000000e+06
# Iter  172 | Loss = 1.389176e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.039590e+06, target fluence: 1.000000e+06
# Iter  173 | Loss = 1.353767e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.039656e+06, target fluence: 1.000000e+06
# Iter  174 | Loss = 1.319450e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.039722e+06, target fluence: 1.000000e+06
# Iter  175 | Loss = 1.286195e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.039786e+06, target fluence: 1.000000e+06
# Iter  176 | Loss = 1.253977e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.039850e+06, target fluence: 1.000000e+06
# Iter  177 | Loss = 1.222767e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.039912e+06, target fluence: 1.000000e+06
# Iter  178 | Loss = 1.192535e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.039974e+06, target fluence: 1.000000e+06
# Iter  179 | Loss = 1.163248e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.040036e+06, target fluence: 1.000000e+06
# [0.1, 0.1]
# Iter  180 | Loss = 1.134876e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.040098e+06, target fluence: 1.000000e+06
# Iter  181 | Loss = 1.107384e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.040160e+06, target fluence: 1.000000e+06
# Iter  182 | Loss = 1.080738e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.040222e+06, target fluence: 1.000000e+06
# Iter  183 | Loss = 1.054903e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.040284e+06, target fluence: 1.000000e+06
# Iter  184 | Loss = 1.029846e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.040346e+06, target fluence: 1.000000e+06
# Iter  185 | Loss = 1.005535e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.040408e+06, target fluence: 1.000000e+06
# Iter  186 | Loss = 9.819443e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.040470e+06, target fluence: 1.000000e+06
# Iter  187 | Loss = 9.590428e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.040532e+06, target fluence: 1.000000e+06
# Iter  188 | Loss = 9.368038e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.040595e+06, target fluence: 1.000000e+06
# Iter  189 | Loss = 9.152056e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.040659e+06, target fluence: 1.000000e+06
# Iter  190 | Loss = 8.942248e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.040724e+06, target fluence: 1.000000e+06
# Iter  191 | Loss = 8.738404e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.040790e+06, target fluence: 1.000000e+06
# Iter  192 | Loss = 8.540350e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.040858e+06, target fluence: 1.000000e+06
# Iter  193 | Loss = 8.347894e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.040926e+06, target fluence: 1.000000e+06
# Iter  194 | Loss = 8.160886e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.040995e+06, target fluence: 1.000000e+06
# Iter  195 | Loss = 7.979154e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.041063e+06, target fluence: 1.000000e+06
# Iter  196 | Loss = 7.802541e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.041132e+06, target fluence: 1.000000e+06
# Iter  197 | Loss = 7.630878e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.041200e+06, target fluence: 1.000000e+06
# Iter  198 | Loss = 7.464037e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.041267e+06, target fluence: 1.000000e+06
# Iter  199 | Loss = 7.301818e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.041335e+06, target fluence: 1.000000e+06
# ...
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.050321e+06, target fluence: 1.000000e+06
# Iter  607 | Loss = 7.342477e+02 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.050060e+06, target fluence: 1.000000e+06
# Iter  608 | Loss = 7.508453e+02 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.050280e+06, target fluence: 1.000000e+06
# Iter  609 | Loss = 7.492219e+02 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.049990e+06, target fluence: 1.000000e+06
# Iter  610 | Loss = 7.788541e+02 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.050256e+06, target fluence: 1.000000e+06
# Iter  611 | Loss = 7.907522e+02 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.049906e+06, target fluence: 1.000000e+06
# Iter  612 | Loss = 8.447892e+02 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.050244e+06, target fluence: 1.000000e+06
# Iter  613 | Loss = 8.799318e+02 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Freeing all parameters.
# Calculated fluence from probe amplitude: 1.049794e+06, target fluence: 1.000000e+06
# Iter  614 | Loss = 9.696342e+02 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[97], line 44
#      40 probe_randomisation = False # Randomise the probe at the start of the optimization to help escape local minima
#      41 randomisation_dict = {'object_randomisation': object_randomisation, 'probe_randomisation': probe_randomisation,
#      42                       'object_rand_pf': 0.15, 'probe_rand_pf': 0.1, 'iter_spacing': 5, 'final_iteration': 50}
# ---> 44 result = optimize_object_and_probe_with_scheduler(scan, pol_angles, I_sim, H, W,
#      45                                    initial_probe_amplitude=initial_probe_amplitude,
#      46                                    initial_l=initial_l,
#      47                                    num_iterations=1000, device=device,
#      48                                    loss_prefactors=loss_prefactors, object_randomisation=object_randomisation,
#      49                                    probe_randomisation=probe_randomisation, optimizer_params=optimizer_params)
#
# Cell In[94], line 219, in optimize_object_and_probe_with_scheduler(scan, pol_angles, I_meas, H, W, initial_l, initial_probe_amplitude, num_iterations, device, loss_prefactors, optimizer_params, plot_filename, object_randomisation, probe_randomisation)
#     217         l_mag = torch.sqrt(torch.sum(l**2, dim=0) + eps)
#     218         print(f"Iter {iteration:4d} | Loss = {loss.item():.6e} | C, A1, A2: {C.item():.6e}, {A1.item():.6e}, {A2.item():.6e}")
# --> 219         plot_update(probe_amplitude, theta, phi, loss, save_filename=plot_filename)
#     221 return {
#     222     "l": l.detach(),
#     223     "probe_amplitude": probe_amplitude.detach(),
#    (...)
#     229     "loss_prefactors": loss_prefactors,
#     230 }
#
# File ~\OneDrive - Nexus365\Documents\Google Drive (old computer 12_07_2022)\PhD\Year 3\Term 1\Ptycho\vector-ptycho\src\vector_ptycho\utils.py:278, in create_live_plotter.<locals>.update(probe_amplitude, theta, phi, loss, save_filename)
#     275 if save_filename is not None:
#     276     fig.savefig(save_filename, bbox_inches='tight')
# --> 278 display_handle.update(fig)
#
# File c:\Users\godfrey\OneDrive - Nexus365\Documents\Google Drive (old computer 12_07_2022)\PhD\Year 3\Term 1\Ptycho\vector-ptycho\.venv\lib\site-packages\IPython\core\display_functions.py:374, in DisplayHandle.update(self, obj, **kwargs)
#     364 def update(self, obj, **kwargs):
#     365     """Update existing displays with my id
#     366
#     367     Parameters
#    (...)
#     372         additional keyword arguments passed to update_display
#     373     """
# --> 374     update_display(obj, display_id=self.display_id, **kwargs)
#
# File c:\Users\godfrey\OneDrive - Nexus365\Documents\Google Drive (old computer 12_07_2022)\PhD\Year 3\Term 1\Ptycho\vector-ptycho\.venv\lib\site-packages\IPython\core\display_functions.py:326, in update_display(obj, display_id, **kwargs)
#     312 """Update an existing display by id
#     313
#     314 Parameters
#    (...)
#     323 :func:`display`
#     324 """
#     325 kwargs['update'] = True
# --> 326 display(obj, display_id=display_id, **kwargs)
#
# File c:\Users\godfrey\OneDrive - Nexus365\Documents\Google Drive (old computer 12_07_2022)\PhD\Year 3\Term 1\Ptycho\vector-ptycho\.venv\lib\site-packages\IPython\core\display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File c:\Users\godfrey\OneDrive - Nexus365\Documents\Google Drive (old computer 12_07_2022)\PhD\Year 3\Term 1\Ptycho\vector-ptycho\.venv\lib\site-packages\IPython\core\formatters.py:179, in DisplayFormatter.format(self, obj, include, exclude)
#     177 md = None
#     178 try:
# --> 179     data = formatter(obj)
#     180 except:
#     181     # FIXME: log the exception
#     182     raise
#
# File c:\Users\godfrey\OneDrive - Nexus365\Documents\Google Drive (old computer 12_07_2022)\PhD\Year 3\Term 1\Ptycho\vector-ptycho\.venv\lib\site-packages\decorator.py:235, in decorate.<locals>.fun(*args, **kw)
#     233 if not kwsyntax:
#     234     args, kw = fix(args, kw, sig)
# --> 235 return caller(func, *(extras + args), **kw)
#
# File c:\Users\godfrey\OneDrive - Nexus365\Documents\Google Drive (old computer 12_07_2022)\PhD\Year 3\Term 1\Ptycho\vector-ptycho\.venv\lib\site-packages\IPython\core\formatters.py:223, in catch_format_error(method, self, *args, **kwargs)
#     221 """show traceback on failed format call"""
#     222 try:
# --> 223     r = method(self, *args, **kwargs)
#     224 except NotImplementedError:
#     225     # don't warn on NotImplementedErrors
#     226     return self._check_return(None, args[0])
#
# File c:\Users\godfrey\OneDrive - Nexus365\Documents\Google Drive (old computer 12_07_2022)\PhD\Year 3\Term 1\Ptycho\vector-ptycho\.venv\lib\site-packages\IPython\core\formatters.py:340, in BaseFormatter.__call__(self, obj)
#     338     pass
#     339 else:
# --> 340     return printer(obj)
#     341 # Finally look for special method names
#     342 method = get_real_method(obj, self.print_method)
#
# File c:\Users\godfrey\OneDrive - Nexus365\Documents\Google Drive (old computer 12_07_2022)\PhD\Year 3\Term 1\Ptycho\vector-ptycho\.venv\lib\site-packages\IPython\core\pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File c:\Users\godfrey\OneDrive - Nexus365\Documents\Google Drive (old computer 12_07_2022)\PhD\Year 3\Term 1\Ptycho\vector-ptycho\.venv\lib\site-packages\matplotlib\backend_bases.py:2175, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2172     # we do this instead of `self.figure.draw_without_rendering`
#    2173     # so that we can inject the orientation
#    2174     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2175         self.figure.draw(renderer)
#    2176 if bbox_inches:
#    2177     if bbox_inches == "tight":
#
# File c:\Users\godfrey\OneDrive - Nexus365\Documents\Google Drive (old computer 12_07_2022)\PhD\Year 3\Term 1\Ptycho\vector-ptycho\.venv\lib\site-packages\matplotlib\artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File c:\Users\godfrey\OneDrive - Nexus365\Documents\Google Drive (old computer 12_07_2022)\PhD\Year 3\Term 1\Ptycho\vector-ptycho\.venv\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\godfrey\OneDrive - Nexus365\Documents\Google Drive (old computer 12_07_2022)\PhD\Year 3\Term 1\Ptycho\vector-ptycho\.venv\lib\site-packages\matplotlib\figure.py:3162, in Figure.draw(self, renderer)
#    3159             # ValueError can occur when resizing a window.
#    3161     self.patch.draw(renderer)
# -> 3162     mimage._draw_list_compositing_images(
#    3163         renderer, self, artists, self.suppressComposite)
#    3165     renderer.close_group('figure')
#    3166 finally:
#
# File c:\Users\godfrey\OneDrive - Nexus365\Documents\Google Drive (old computer 12_07_2022)\PhD\Year 3\Term 1\Ptycho\vector-ptycho\.venv\lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File c:\Users\godfrey\OneDrive - Nexus365\Documents\Google Drive (old computer 12_07_2022)\PhD\Year 3\Term 1\Ptycho\vector-ptycho\.venv\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\godfrey\OneDrive - Nexus365\Documents\Google Drive (old computer 12_07_2022)\PhD\Year 3\Term 1\Ptycho\vector-ptycho\.venv\lib\site-packages\matplotlib\axes\_base.py:3137, in _AxesBase.draw(self, renderer)
#    3134 if artists_rasterized:
#    3135     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3137 mimage._draw_list_compositing_images(
#    3138     renderer, self, artists, self.figure.suppressComposite)
#    3140 renderer.close_group('axes')
#    3141 self.stale = False
#
# File c:\Users\godfrey\OneDrive - Nexus365\Documents\Google Drive (old computer 12_07_2022)\PhD\Year 3\Term 1\Ptycho\vector-ptycho\.venv\lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File c:\Users\godfrey\OneDrive - Nexus365\Documents\Google Drive (old computer 12_07_2022)\PhD\Year 3\Term 1\Ptycho\vector-ptycho\.venv\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\godfrey\OneDrive - Nexus365\Documents\Google Drive (old computer 12_07_2022)\PhD\Year 3\Term 1\Ptycho\vector-ptycho\.venv\lib\site-packages\matplotlib\axis.py:1424, in Axis.draw(self, renderer)
#    1421 renderer.open_group(__name__, gid=self.get_gid())
#    1423 ticks_to_draw = self._update_ticks()
# -> 1424 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    1426 for tick in ticks_to_draw:
#    1427     tick.draw(renderer)
#
# File c:\Users\godfrey\OneDrive - Nexus365\Documents\Google Drive (old computer 12_07_2022)\PhD\Year 3\Term 1\Ptycho\vector-ptycho\.venv\lib\site-packages\matplotlib\axis.py:1351, in Axis._get_ticklabel_bboxes(self, ticks, renderer)
#    1349 if renderer is None:
#    1350     renderer = self.figure._get_renderer()
# -> 1351 return ([tick.label1.get_window_extent(renderer)
#    1352          for tick in ticks if tick.label1.get_visible()],
#    1353         [tick.label2.get_window_extent(renderer)
#    1354          for tick in ticks if tick.label2.get_visible()])
#
# File c:\Users\godfrey\OneDrive - Nexus365\Documents\Google Drive (old computer 12_07_2022)\PhD\Year 3\Term 1\Ptycho\vector-ptycho\.venv\lib\site-packages\matplotlib\axis.py:1351, in <listcomp>(.0)
#    1349 if renderer is None:
#    1350     renderer = self.figure._get_renderer()
# -> 1351 return ([tick.label1.get_window_extent(renderer)
#    1352          for tick in ticks if tick.label1.get_visible()],
#    1353         [tick.label2.get_window_extent(renderer)
#    1354          for tick in ticks if tick.label2.get_visible()])
#
# File c:\Users\godfrey\OneDrive - Nexus365\Documents\Google Drive (old computer 12_07_2022)\PhD\Year 3\Term 1\Ptycho\vector-ptycho\.venv\lib\site-packages\matplotlib\text.py:961, in Text.get_window_extent(self, renderer, dpi)
#     959 bbox, info, descent = self._get_layout(self._renderer)
#     960 x, y = self.get_unitless_position()
# --> 961 x, y = self.get_transform().transform((x, y))
#     962 bbox = bbox.translated(x, y)
#     963 return bbox
#
# File c:\Users\godfrey\OneDrive - Nexus365\Documents\Google Drive (old computer 12_07_2022)\PhD\Year 3\Term 1\Ptycho\vector-ptycho\.venv\lib\site-packages\matplotlib\transforms.py:1505, in Transform.transform(self, values)
#    1502 values = values.reshape((-1, self.input_dims))
#    1504 # Transform the values
# -> 1505 res = self.transform_affine(self.transform_non_affine(values))
#    1507 # Convert the result back to the shape of the input values.
#    1508 if ndim == 0:
#
# File c:\Users\godfrey\OneDrive - Nexus365\Documents\Google Drive (old computer 12_07_2022)\PhD\Year 3\Term 1\Ptycho\vector-ptycho\.venv\lib\site-packages\matplotlib\_api\deprecation.py:300, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     295     warn_deprecated(
#     296         since, message=f"The {old!r} parameter of {func.__name__}() "
#     297         f"has been renamed {new!r} since Matplotlib {since}; support "
#     298         f"for the old name will be dropped %(removal)s.")
#     299     kwargs[new] = kwargs.pop(old)
# --> 300 return func(*args, **kwargs)
#
# File c:\Users\godfrey\OneDrive - Nexus365\Documents\Google Drive (old computer 12_07_2022)\PhD\Year 3\Term 1\Ptycho\vector-ptycho\.venv\lib\site-packages\matplotlib\transforms.py:2428, in CompositeGenericTransform.transform_affine(self, values)
#    2425 @_api.rename_parameter("3.8", "points", "values")
#    2426 def transform_affine(self, values):
#    2427     # docstring inherited
# -> 2428     return self.get_affine().transform(values)
#
# File c:\Users\godfrey\OneDrive - Nexus365\Documents\Google Drive (old computer 12_07_2022)\PhD\Year 3\Term 1\Ptycho\vector-ptycho\.venv\lib\site-packages\matplotlib\transforms.py:2455, in CompositeGenericTransform.get_affine(self)
#    2453     return self._b.get_affine()
#    2454 else:
# -> 2455     return Affine2D(np.dot(self._b.get_affine().get_matrix(),
#    2456                            self._a.get_affine().get_matrix()))
#
# KeyboardInterrupt:

# %% [markdown]
# ## Loop through a few different hyperparameters

# %%
import itertools
import pickle
import os

# Initial probe and object
initial_theta = torch.nn.Parameter(torch.rand((H, W), device=device) * 0.01 + torch.pi/2)
initial_phi   = torch.nn.Parameter(torch.rand((H, W), device=device) * 0.1 + torch.pi/2)

P_test = torch.zeros_like(R)
Diffuser = torch.rand((H, W), device=device)
P_test = torch.exp(2j*np.pi*Diffuser)*(torch.exp(-0.8*R))
initial_probe_amplitude = P_test


# --- hyperparameter ranges ---
gradient_pf_list = [1.0, 1e-1, 1e-1]
anisotropy_pf_list = [1.0, 1e-1, 1e-1]

base_loss_prefactors = {
    'sqrt_amp_pf': 1.0,
}

optimizer_params = {
    'theta_lr': 5e-1,
    'phi_lr': 5e-1,
    'CA_lr': 1e-5,
    'probe_lr': 60e-1
}

output_dir = "hyperparam_runs"
os.makedirs(output_dir, exist_ok=True)

# --- loop ---
for gradient_pf, anisotropy_pf in itertools.product(gradient_pf_list, anisotropy_pf_list):
    
    loss_prefactors = {
        **base_loss_prefactors,
        'gradient_pf': gradient_pf,
        'anisotropy_pf': anisotropy_pf
    }
    
    run_name = f"grad_{gradient_pf:.0e}_anis_{anisotropy_pf:.0e}"
    
    plot_filename = os.path.join(output_dir, f"plot_{run_name}.png")
    pickle_filename = os.path.join(output_dir, f"result_{run_name}.pkl")
    
    print(f"Running: {run_name}")
    
    result = optimize_object_and_probe_with_scheduler(
        scan, pol_angles, I_sim, H, W,
        initial_theta=initial_theta,
        initial_phi=initial_phi,
        initial_probe_amplitude=initial_probe_amplitude,
        num_iterations=80,
        device=device,
        loss_prefactors=loss_prefactors,
        plot_filename=plot_filename
    )
    
    # optional: include params explicitly in saved object
    result_to_save = {
        "run_name": run_name,
        "gradient_pf": gradient_pf,
        "anisotropy_pf": anisotropy_pf,
        "result": result
    }
    
    # save immediately
    with open(pickle_filename, "wb") as f:
        pickle.dump(result_to_save, f)

    print(f"Saved: {pickle_filename}")

# %%
import os
import pickle
import glob
import matplotlib.pyplot as plt

results_dir = "hyperparam_runs"

# find all pickle files
pickle_files = sorted(glob.glob(os.path.join(results_dir, "result_*.pkl")))

plt.figure()

for pf in pickle_files:
    with open(pf, "rb") as f:
        data = pickle.load(f)
    
    run_name = data["run_name"]
    loss_history = data["result"]["loss_history"]
    
    plt.plot(loss_history, label=run_name)

plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.yscale("log")
plt.title("Loss history for different hyperparameters")

# optional: legend can get crowded
plt.legend(fontsize=8)
plt.tight_layout()
plt.show()

# %%
plot_probe_maps(result["probe_amplitude"].detach().cpu().numpy(), Lx, Ly)
plot_theta_phi_maps(
    result["theta"].detach().cpu().numpy(),
    result["phi"].detach().cpu().numpy(),
    Lx,
    Ly,
    theta_cmap='magma',
    phi_cmap=RGB_scale,
    label_axes=True,
)

# %%
plt.plot(result["loss_history"])
plt.ylabel('Loss')
plt.xlabel('Iteration')
plt.yscale('log')
plt.show()
