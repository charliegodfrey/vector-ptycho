# %% [markdown]
# # Updating probe and object
# ## Using Mx, My, Mz rather than polar angles and normalising after every iteration.
# ## Now keeping C, A1, A2 fixed.

# %%
import importlib
import vector_ptycho.utils as vpu
importlib.reload(vpu)
from vector_ptycho.utils import *
import numpy as np
import matplotlib.pyplot as plt
import torch
import pickle
from IPython.display import display
from vector_ptycho.utils import _to_numpy

# %%
RGB_scale = make_vector_color_map(plot=False)

# %% [markdown]
# ## Define the object, probe, fluence and XMLD constants

# %%
H, W = 100, 100
Lx = 5
Ly = 5

# Build theta, phi from meron-antimeron generator (returns torch tensors)
theta, phi, Mx, My, Mz = make_meron_antimeron_theta_phi(
    Nx=W,
    Ny=H,
    Lx=Lx,
    Ly=Ly,
    plot=False,
    save_path=None,
    export_path=None,
    return_torch=True,
    out_device=device,
    cm = RGB_scale,
)

# Physical XMLD/Jones constants
C = torch.tensor(50.0+ 50.0j, dtype=cdtype, device=device)
A1 = torch.tensor(1 + 3j, dtype=cdtype, device=device)
A2 = torch.tensor(5 + 2j, dtype=cdtype, device=device)

# Build Jones object from theta, phi
neel = NeelObject(C, A1, A2)
J = neel.build_jones(theta, phi)
obj = JonesObject(J)

# Grid for probe definition
x = torch.linspace(-Lx, Lx, H, device=device)
y = torch.linspace(-Ly, Ly, W, device=device)
X, Y = torch.meshgrid(x, y, indexing='ij')

# Define a probe with some phase structure on the wavefront.
fluence = torch.scalar_tensor(1e6, dtype=torch.float64, device=device)
R=torch.sqrt(X**2+Y**2) #This helps with defining the probe
R_probe = 1.0
Diffuser = 0.1*(torch.sin(1*R)+torch.cos((Y*5+X*1)-0.8*(X-0.2))+torch.cos((Y-X)-0.4*(X)))*(R<R_probe) #(torch.sqrt(3*X**2+1.5*Y**2)+torch.pi/3)#*(torch.exp(-0.1*R)) #np.mod(0.1*(torch.sin(150*R)+torch.cos((Y*10+X*30)**2-0.8*(X*75-0.2))+torch.cos((Y*10-X*33)**2-0.4*(X*50-0.2))),1)
P = torch.zeros_like(R)
P = torch.exp(2j*np.pi*Diffuser)*(R<R_probe)#*(torch.exp(-0.8*R))

# Calculate the Jones vectors of the probes for different Linear polarisation states
probes = []
pol_angles = [0, 30, 60, 90]#, 120, 150, 180]
for angle in pol_angles:
    rad = np.deg2rad(angle)
    jones_vec = torch.tensor([np.cos(rad) + 0j, np.sin(rad) + 0j], dtype=cdtype, device=device)
    print(f'Jones vector for {angle} deg linear polarisation: {jones_vec}')
    probes.append(Probe(P, jones_vec, fluence=fluence, normalized=False))

print('Defined {} probes with different linear polarisation states.'.format(len(probes)))


plot_probe_maps(probes[0].amplitude, Lx, Ly)
print('Probe fluence:', probes[0].fluence)
# Out:
# Jones vector for 0 deg linear polarisation: tensor([1.+0.j, 0.+0.j])
# Jones vector for 30 deg linear polarisation: tensor([0.8660+0.j, 0.5000+0.j])
# Jones vector for 60 deg linear polarisation: tensor([0.5000+0.j, 0.8660+0.j])
# Jones vector for 90 deg linear polarisation: tensor([6.1232e-17+0.j, 1.0000e+00+0.j])
# Defined 4 probes with different linear polarisation states.
# Probe fluence: tensor(1000000., dtype=torch.float64)

# %% [markdown]
# # Define the scan trajectory, simulate the detector

# %%
xshiftvec = torch.linspace(-2.5, 2.5,6)
yshiftvec = torch.linspace(-2.5, 2.5,6)

# Shifting the text so that we can plot on the data
dx = (xshiftvec[1] - xshiftvec[0]) / 10
dy = (yshiftvec[1] - yshiftvec[0]) / 10

# Lab-coordinate scan grid used for plotting
xpos_lab, ypos_lab = torch.meshgrid(xshiftvec, yshiftvec, indexing="ij")
positions = torch.stack([ypos_lab.flatten(), xpos_lab.flatten()], dim=1)

# Convert lab coordinates into discrete pixel shifts for torch.roll(row, col)
pixel_size_y = (2 * Ly) / (H - 1)
pixel_size_x = (2 * Lx) / (W - 1)
positions_idx = torch.stack([
    torch.round(positions[:, 0] / pixel_size_y),
    torch.round(positions[:, 1] / pixel_size_x),
], dim=1).to(torch.int64)

scan = ScanTrajectory(positions_idx)

# Forward model
model = ForwardModel(obj, Propagator(), Detector(add_poisson_noise=True))
I_sim = model.simulate_all(probes, scan)
print('Simulated data shape:', I_sim.shape)  # (N_probes, N_positions, H, W)
# Out:
# C:\Users\godfrey\OneDrive - Nexus365\Documents\Google Drive (old computer 12_07_2022)\PhD\Year 3\Term 1\Ptycho\vector-ptycho\src\vector_ptycho\utils.py:483: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.positions = torch.tensor(positions, device=device)
# Simulated data shape: torch.Size([4, 36, 100, 100])

# %%
plot_theta_phi_maps(theta, phi, Lx, Ly,theta_cmap='magma',
                       phi_cmap=RGB_scale,
                       positions=positions, dx=0.3, dy=0.3, show_positions=True, label_positions=True, label_axes=True)
# Out:
# (<Figure size 1200x500 with 4 Axes>,
#  array([<Axes: title={'center': '$l_z$ heatmap'}, xlabel='$x$ [m]', ylabel='$y$ [m]'>,
#         <Axes: title={'center': '$\\phi$ heatmap'}, xlabel='$x$ [m]', ylabel='$y$ [m]'>],
#        dtype=object))

# %%
# Normalise I_sim for the autograd - divide by the mean to keep values around 1, which helps with the gradients - now l has a magnitude of 1, probe and detector have values around 1, so the gradients are nicely balanced and we don't have to worry about vanishing or exploding gradients as much.
I_sim_norm = I_sim / I_sim.mean()

# %%
fig, axes = plt.subplots(4, 4, figsize=(12, 12))

#scan_indices = [35, 36, 45, 43]
scan_indices = [1, 2, 20, 24]
probe_numbers = [0, 1, 2, 3]

for i, probe_number in enumerate(probe_numbers):      # rows
    for j, scan_idx in enumerate(scan_indices):       # columns
        
        axes[i, j].imshow(
            (np.log10(I_sim[probe_number, scan_idx].cpu()+1e-8)),
            cmap='inferno',
            vmax=8e-1
        )
        
        '''
        axes[i, j].imshow(
            np.log10(I_sim[probe_number, scan_idx].cpu()+1e-8),
            cmap='inferno',
        )
        '''
        axes[i, j].set_title(f'Probe {probe_number}, Pos {scan_idx}, x={positions[scan_idx, 0].item():.2f}, y={positions[scan_idx, 1].item():.2f}')
        axes[i, j].axis('off')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\godfrey\AppData\Local\Temp\ipykernel_10836\1341887378.py:11: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   (np.log10(I_sim[probe_number, scan_idx].cpu()+1e-8)),

# %%
def normalise_neel(l):
    # Normalize to ensure L is always a unit vector
    mag = torch.sqrt(torch.sum(l**2, dim=0) + 1e-8)
    Lx = l[0] / mag
    Ly = l[1] / mag
    Lz = l[2] / mag
    return Lx, Ly, Lz

def optimize_object(scan, pol_angles, I_meas, H, W, initial_l, initial_probe_amplitude,num_iterations=100, device=None,
                                             optimizer_params={'l_lr': 1e-1, 'CA_lr': 1e-5},
                                             plot_filename=None):
    """
    Reconstruct probes (different for each polarisation) l C, A1, A2 from measured diffraction patterns.
    This is different to previous versions because it directly updates lx, ly, lz to avoid differentiation problems associated with angular coordinates.
    .
    Parameters
    ----------
    scan : ScanTrajectory
        Scan positions.
    pol_angles : list of float
        List of polarisation angles in degrees for each probe.
    I_meas : torch.Tensor
        Measured diffraction intensities, shape (N_probes, N_scan, Hdet, Wdet)
    H, W : int
        Object map size.
    initial_l : torch.Tensor
        Initial guess for the neel vector in Cartesian coordinates, shape (3, H, W).
    initial_probe_amplitude : torch.Tensor
        Initial guess for the probe amplitude, shape (H, W).
    num_iterations : int
        Number of optimization steps.
    device : torch.device or str
        Device to use.
    loss_prefactors : dict
        Prefactors for different loss components - how much to weight anisotropy and gradient losses relative to the amplitude loss.
    optimizer_params : dict
        Learning rates for different parameter groups in the optimizer.
    plot_filename : str or None
        If not None, save intermediate plots to this filename during optimization.
     Returns
    -------
    dict
        Reconstructed parameters and loss history.
    """
    if device is None:
        device = I_meas.device

    # This is for the live plot updates
    plot_update = create_live_plotter(Lx, Ly, phi_cmap=RGB_scale, theta_cmap='magma')

    eps = 1e-12
    cdtype = torch.complex64

    # Learnable parameters

    l = torch.nn.Parameter(initial_l) # Defining the neel vector in terms of it's lx, ly, lz components, which are then normalised to get theta and phi. This is easier to optimise than directly optimising theta and phi, which have singularities at the poles.
    probe_amplitude = initial_probe_amplitude

    # Initialise the probe array (same for all pol states at the moment)
    probes = []
    for angle in pol_angles:
        rad = np.deg2rad(angle)
        jones_vec = torch.tensor([np.cos(rad) + 0j, np.sin(rad) + 0j], dtype=cdtype, device=device)
        probes.append(Probe(probe_amplitude, jones_vec, fluence=fluence, normalized=False))
    probe_amplitude = (probes[0].amplitude) #It has now been normalised to the correct fluence.
    probe_amplitude_start = probes[0].amplitude
    fluence_calc = torch.sum(torch.abs(probe_amplitude_start)**2)
    print(f"Calculated initial fluence from probe amplitude: {fluence_calc.item():.6e}, target fluence: {fluence.item():.6e}")

    optimizer = torch.optim.AdamW([
        {"params": [l], "lr": optimizer_params['l_lr']},
        {"params": [C, A1, A2], "lr": optimizer_params['CA_lr']}
        ])
    
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer,
        mode='min',
        factor=0.5,       # reduce LR by 2x
        patience=5,      # wait 5 iterations without improvement
        threshold=1e-3,   # minimum change to count as improvement
        min_lr=1e-6,      # don't go too small
    )
    loss_history = []

    for iteration in range(num_iterations):
        optimizer.zero_grad(set_to_none=True)

        l_mag = torch.sqrt(torch.sum(l**2, dim=0) + 1e-8) 
        
        # Create normalized Cartesian components
        lx_norm = l[0] / l_mag
        ly_norm = l[1] / l_mag
        lz_norm = l[2] / l_mag

        # Build Jones object from current parameters
        neel = NeelObject(C, A1, A2)
        J = neel.build_jones_from_cartesian(lx= lx_norm, ly=ly_norm, lz=lz_norm)
        obj = JonesObject(J)

        # Remake the probe array
        probes = []
        for angle in pol_angles:
            rad = np.deg2rad(angle)
            jones_vec = torch.tensor([np.cos(rad) + 0j, np.sin(rad) + 0j], dtype=cdtype, device=device)
            probes.append(Probe(probe_amplitude, jones_vec, fluence=fluence, normalized=True))

        # Forward model
        model = ForwardModel(obj, Propagator(), Detector())
        I_pred = model.simulate_all(probes, scan)
        eps = 1e-8

        fluence_calc = torch.sum(torch.abs(probe_amplitude)**2)
        print(f"Calculated fluence from probe amplitude: {fluence_calc.item():.6e}, target fluence: {fluence.item():.6e}")

        # Define the loss function
        loss = torch.mean((torch.sqrt(I_pred + eps) - torch.sqrt(I_meas + eps))**2)

        loss.backward()
        optimizer.step()

        # Step the scheduler with the current loss
        scheduler.step(loss)

        if iteration % 20 == 0:
            print([group['lr'] for group in optimizer.param_groups])

        loss_history.append(loss.item())

        if iteration % 1 == 0:
            theta = torch.acos(lz_norm)
            phi = torch.atan2(ly_norm, lx_norm)
            l_mag = torch.sqrt(torch.sum(l**2, dim=0) + 1e-8)
            print(f"Iter {iteration:4d} | Loss = {loss.item():.6e}")
            plot_update(probe_amplitude, theta, phi, loss, save_filename=plot_filename)

    return {
        "l": l.detach(),
        "probe_amplitude": probe_amplitude.detach(),
        "C": C.detach(),
        "A1": A1.detach(),
        "A2": A2.detach(),
        "loss_history": loss_history,
        "optimizer_params": optimizer_params  
    }

'''
initial_l = torch.stack([
    torch.randn(H, W, device=device)*0.1,
    torch.randn(H, W, device=device)*1,
    torch.randn(H, W, device=device)*0.1
])
'''
initial_l = torch.randn(3, H, W, device=device)
result = optimize_object(scan, pol_angles, I_sim, H, W,
                                initial_probe_amplitude=P,
                                initial_l=initial_l,
                                num_iterations=800, device=device)
# Out:
# Calculated initial fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 154
#     146 '''
#     147 initial_l = torch.stack([
#     148     torch.randn(H, W, device=device)*0.1,
#    (...)
#     151 ])
#     152 '''
#     153 initial_l = torch.randn(3, H, W, device=device)
# --> 154 result = optimize_object(scan, pol_angles, I_sim, H, W,
#     155                                 initial_probe_amplitude=P,
#     156                                 initial_l=initial_l,
#     157                                 num_iterations=800, device=device)
#
# Cell In[37], line 118, in optimize_object(scan, pol_angles, I_meas, H, W, initial_l, initial_probe_amplitude, num_iterations, device, optimizer_params, plot_filename)
#     115 # Define the loss function
#     116 loss = torch.mean((torch.sqrt(I_pred + eps) - torch.sqrt(I_meas + eps))**2)
# --> 118 loss.backward()
#     119 optimizer.step()
#     121 # Step the scheduler with the current loss
#
# File c:\Users\godfrey\OneDrive - Nexus365\Documents\Google Drive (old computer 12_07_2022)\PhD\Year 3\Term 1\Ptycho\vector-ptycho\.venv\lib\site-packages\torch\_tensor.py:647, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     637 if has_torch_function_unary(self):
#     638     return handle_torch_function(
#     639         Tensor.backward,
#     640         (self,),
#    (...)
#     645         inputs=inputs,
#     646     )
# --> 647 torch.autograd.backward(
#     648     self, gradient, retain_graph, create_graph, inputs=inputs
#     649 )
#
# File c:\Users\godfrey\OneDrive - Nexus365\Documents\Google Drive (old computer 12_07_2022)\PhD\Year 3\Term 1\Ptycho\vector-ptycho\.venv\lib\site-packages\torch\autograd\__init__.py:354, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     349     retain_graph = create_graph
#     351 # The reason we repeat the same comment below is that
#     352 # some Python versions print out the first line of a multi-line function
#     353 # calls in the traceback and some print out the last line
# --> 354 _engine_run_backward(
#     355     tensors,
#     356     grad_tensors_,
#     357     retain_graph,
#     358     create_graph,
#     359     inputs_tuple,
#     360     allow_unreachable=True,
#     361     accumulate_grad=True,
#     362 )
#
# File c:\Users\godfrey\OneDrive - Nexus365\Documents\Google Drive (old computer 12_07_2022)\PhD\Year 3\Term 1\Ptycho\vector-ptycho\.venv\lib\site-packages\torch\autograd\graph.py:829, in _engine_run_backward(t_outputs, *args, **kwargs)
#     827     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     828 try:
# --> 829     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     830         t_outputs, *args, **kwargs
#     831     )  # Calls into the C++ engine to run the backward pass
#     832 finally:
#     833     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
def normalise_neel(l):
    # Normalize to ensure L is always a unit vector
    mag = torch.sqrt(torch.sum(l**2, dim=0) + 1e-8)
    Lx = l[0] / mag
    Ly = l[1] / mag
    Lz = l[2] / mag
    return Lx, Ly, Lz

def optimize_object_and_probe_with_scheduler(scan, pol_angles, I_meas, H, W, initial_l, initial_probe_amplitude,num_iterations=100, device=None, 
                                             loss_prefactors={'sqrt_amp_pf': 1.0, 'gradient_pf': 1e-4, 'anisotropy_pf': 1e-4, 'probe_localisation_pf': 1e-3},
                                             optimizer_params={'l_lr': 1e-3, 'CA_lr': 1e-5, 'probe_lr': 60e-1},
                                             plot_filename=None, object_randomisation=False, probe_randomisation=False):
    """
    Reconstruct probes (different for each polarisation) l C, A1, A2 from measured diffraction patterns.
    This is different to previous versions because it directly updates lx, ly, lz to avoid differentiation problems associated with angular coordinates.
    .
    Parameters
    ----------
    scan : ScanTrajectory
        Scan positions.
    pol_angles : list of float
        List of polarisation angles in degrees for each probe.
    I_meas : torch.Tensor
        Measured diffraction intensities, shape (N_probes, N_scan, Hdet, Wdet)
    H, W : int
        Object map size.
    initial_l : torch.Tensor
        Initial guess for the neel vector in Cartesian coordinates, shape (3, H, W).
    initial_probe_amplitude : torch.Tensor
        Initial guess for the probe amplitude, shape (H, W).
    num_iterations : int
        Number of optimization steps.
    device : torch.device or str
        Device to use.
    loss_prefactors : dict
        Prefactors for different loss components - how much to weight anisotropy and gradient losses relative to the amplitude loss.
    optimizer_params : dict
        Learning rates for different parameter groups in the optimizer.
    plot_filename : str or None
        If not None, save intermediate plots to this filename during optimization.
    object_randomisation : bool
        Whether to apply randomisation to the object parameters during optimization to help escape local minima.
    probe_randomisation : bool
        Whether to apply randomisation to the probe parameters during optimization to help escape local minima.
     Returns
    -------
    dict
        Reconstructed parameters and loss history.
    """
    if device is None:
        device = I_meas.device

    # This is for the live plot updates
    plot_update = create_live_plotter(Lx, Ly, phi_cmap=RGB_scale, theta_cmap='magma')

    eps = 1e-12
    cdtype = torch.complex64

    # Learnable parameters

    l = torch.nn.Parameter(initial_l) # Defining the neel vector in terms of it's lx, ly, lz components, which are then normalised to get theta and phi. This is easier to optimise than directly optimising theta and phi, which have singularities at the poles.
    probe_amplitude = initial_probe_amplitude

    # Initialise the probe array (same for all pol states at the moment)
    probes = []
    for angle in pol_angles:
        rad = np.deg2rad(angle)
        jones_vec = torch.tensor([np.cos(rad) + 0j, np.sin(rad) + 0j], dtype=cdtype, device=device)
        probes.append(Probe(probe_amplitude, jones_vec, fluence=fluence, normalized=False))
    probe_amplitude = torch.nn.Parameter(probes[0].amplitude) #It has now been normalised to the correct fluence.
    probe_amplitude_start = probes[0].amplitude
    fluence_calc = torch.sum(torch.abs(probe_amplitude_start)**2)
    print(f"Calculated initial fluence from probe amplitude: {fluence_calc.item():.6e}, target fluence: {fluence.item():.6e}")

    optimizer = torch.optim.AdamW([
        {"params": [l], "lr": optimizer_params['l_lr']}, #{"params": [C, A1, A2], "lr": optimizer_params['CA_lr']},
        {"params": [probe_amplitude], "lr": optimizer_params['probe_lr']}
        ])
    
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer,
        mode='min',
        factor=0.5,       # reduce LR by 2x
        patience=500,      # wait 5 iterations without improvement
        threshold=1e-3,   # minimum change to count as improvement
        min_lr=1e-6,      # don't go too small
    )
    loss_history = []

    for iteration in range(num_iterations):
        
        if iteration < 60:
            for p in [l, C, A1, A2]:
                p.requires_grad_(False)
            probe_amplitude.requires_grad_(True)
        if iteration < 100 and iteration >= 60:
            for p in [l, C, A1, A2]:
                p.requires_grad_(True)
            probe_amplitude.requires_grad_(False)
        if iteration >= 100:
            for p in [l, C, A1, A2]:
                p.requires_grad_(True)
            probe_amplitude.requires_grad_(True)
        
        optimizer.zero_grad(set_to_none=True)

        l_mag = torch.sqrt(torch.sum(l**2, dim=0) + 1e-8) 
        
        # Create normalized Cartesian components
        lx_norm = l[0] / l_mag
        ly_norm = l[1] / l_mag
        lz_norm = l[2] / l_mag

        # Build Jones object from current parameters
        neel = NeelObject(C, A1, A2)
        J = neel.build_jones_from_cartesian(lx= lx_norm, ly=ly_norm, lz=lz_norm)
        obj = JonesObject(J)

        # Remake the probe array
        probes = []
        for angle in pol_angles:
            rad = np.deg2rad(angle)
            jones_vec = torch.tensor([np.cos(rad) + 0j, np.sin(rad) + 0j], dtype=cdtype, device=device)
            probes.append(Probe(probe_amplitude, jones_vec, fluence=fluence, normalized=True))

        # Forward model
        model = ForwardModel(obj, Propagator(), Detector())
        I_pred = model.simulate_all(probes, scan)
        eps = 1e-8

        fluence_calc = torch.sum(torch.abs(probe_amplitude)**2)
        print(f"Calculated fluence from probe amplitude: {fluence_calc.item():.6e}, target fluence: {fluence.item():.6e}")
        '''
        if loss_prefactors['gradient_pf'] > 0 or loss_prefactors['anisotropy_pf'] > 0:
            #Only perform this computation if the prefactors are > 0, as it is quite expensive.

            # 2. Compute spatial gradients using finite differences
            # Differences along the X-axis (width)
            dx_lx = torch.diff(lx_norm, dim=-1)
            dx_ly = torch.diff(ly_norm, dim=-1)
            dx_lz = torch.diff(lz_norm, dim=-1)

            # Differences along the Y-axis (height)
            dy_lx = torch.diff(lx_norm, dim=-2)
            dy_ly = torch.diff(ly_norm, dim=-2)
            dy_lz = torch.diff(lz_norm, dim=-2)

            grad_mag_x = torch.sqrt(dx_lx**2 + dx_ly**2 + dx_lz**2 + 1e-8) # 1e-8 prevents NaN in sqrt at 0
            grad_mag_y = torch.sqrt(dy_lx**2 + dy_ly**2 + dy_lz**2 + 1e-8)

            loss_x = torch.sum(grad_mag_x**2)
            loss_y = torch.sum(grad_mag_y**2)

            gradient_loss = loss_x + loss_y
            anisotropy_loss = torch.sum(l[2]**2) # Positive prefactor will favour IP alignment.
        else:
            gradient_loss = 0.0
            anisotropy_loss = 0.0
        '''
        '''
        # Amplitude-based ptychographic loss
        if loss_prefactors['probe_localisation_pf'] > 0:
            probe_localisation_loss = loss_prefactors['probe_localisation_pf'] * torch.mean(torch.abs(probe_amplitude)**2*R**2) #This stops the probe from drifting by penalising amplitude at large R
        else:
            probe_localisation_loss = 0.0
        '''
        # Define the loss function
        loss = loss_prefactors['sqrt_amp_pf'] * torch.mean((torch.sqrt(I_pred + eps) - torch.sqrt(I_meas + eps))**2) #+ loss_prefactors['gradient_pf'] * gradient_loss + loss_prefactors['anisotropy_pf'] * anisotropy_loss + probe_localisation_loss

        loss.backward()
        optimizer.step()

        # Step the scheduler with the current loss
        scheduler.step(loss)

        if iteration % 20 == 0:
            print([group['lr'] for group in optimizer.param_groups])
        
        if iteration % 8 == 0 and iteration < 30:
            with torch.no_grad():
                if probe_randomisation:
                    probe_amplitude.data += (torch.rand((H, W), device=device) * torch.max(torch.abs(probe_amplitude))*0.25)
                if object_randomisation:
                    for i in range(3):
                        noise = torch.randn_like(l[i])
                        l[i] += 1.5 * noise

        loss_history.append(loss.item())

        if iteration % 1 == 0:
            theta = torch.acos(lz_norm)
            phi = torch.atan2(ly_norm, lx_norm)
            l_mag = torch.sqrt(torch.sum(l**2, dim=0) + 1e-8)
            print(f"Iter {iteration:4d} | Loss = {loss.item():.6e} | C, A1, A2: {C.item():.6e}, {A1.item():.6e}, {A2.item():.6e}")
            plot_update(probe_amplitude, theta, phi, loss, save_filename=plot_filename)

    return {
        "l": l.detach(),
        "probe_amplitude": probe_amplitude.detach(),
        "C": C.detach(),
        "A1": A1.detach(),
        "A2": A2.detach(),
        "loss_history": loss_history,
        "optimizer_params": optimizer_params,
        "loss_prefactors": loss_prefactors,   
    }

# %%
#initial_l = torch.randn(3, H, W, device=device)

initial_l = torch.stack([
    torch.randn(H, W, device=device)*0.1,
    torch.randn(H, W, device=device)*1,
    torch.randn(H, W, device=device)*0.1
])

Diffuser = 0.1*(torch.sin(1*R)+torch.cos((Y*5+X*1)-0.8*(X-0.2))+torch.cos((Y-X)-0.4*(X)))*(R<R_probe) #(torch.sqrt(3*X**2+1.5*Y**2)+torch.pi/3)#*(torch.exp(-0.1*R)) #np.mod(0.1*(torch.sin(150*R)+torch.cos((Y*10+X*30)**2-0.8*(X*75-0.2))+torch.cos((Y*10-X*33)**2-0.4*(X*50-0.2))),1)
Diffuser = torch.zeros_like(R)
Diffuser = torch.randn_like(R)*(R<R_probe)
P_test = torch.zeros_like(R)
P_test = torch.exp(2j*np.pi*Diffuser)*(R<R_probe)#*(torch.exp(-0.8*R))
initial_probe_amplitude = P_test


def normalise_probe_from_data(I_meas_normalized, initial_probe_amplitude):
    # 1. Average the data and take the square root
    I_avg = torch.mean(I_meas_normalized, dim=(0, 1)) # Average over pol states and scan positions

    I_w_initial_p = (torch.abs(F(initial_probe_amplitude))**2)
    scaler = torch.sqrt(torch.sum(I_avg) / (torch.sum(I_w_initial_p) + 1e-8))
    print('Probe scaler:', scaler)
    return initial_probe_amplitude*scaler

#initial_probe_amplitude = normalise_probe_from_data(I_sim_norm, initial_probe_amplitude)
#print('Max of detector with initial probe:', torch.max(torch.abs(F(initial_probe_amplitude))**2))
#print('Max of normalized detector data:', torch.max(I_sim_norm))

optimizer_params={'l_lr': 1e-1, 'CA_lr': 1e-5, 'probe_lr':3e-1}
loss_prefactors={'sqrt_amp_pf': 1.0, 'gradient_pf': 1e-4, 'anisotropy_pf': 1e-4, 'probe_localisation_pf':0.0} # Different parts of the Loss have different weights

'''Randomisation can help a minimum be found - this section tells what gets randomised, by how much and when it stops taking effect'''
object_randomisation = False # Randomise the object at the start of the optimization to help escape local minima
probe_randomisation = False # Randomise the probe at the start of the optimization to help escape local minima
randomisation_dict = {'object_randomisation': object_randomisation, 'probe_randomisation': probe_randomisation,
                      'object_rand_pf': 0.15, 'probe_rand_pf': 0.1, 'iter_spacing': 5, 'final_iteration': 50}

result = optimize_object_and_probe_with_scheduler(scan, pol_angles, I_sim, H, W,
                                   initial_probe_amplitude=initial_probe_amplitude,
                                   initial_l=initial_l,
                                   num_iterations=800, device=device, loss_prefactors=loss_prefactors, object_randomisation=object_randomisation, probe_randomisation=probe_randomisation, optimizer_params=optimizer_params)
# Out:
# Calculated initial fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# [0.1, 0.3]
# Iter    0 | Loss = 6.831321e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 9.882209e+05, target fluence: 1.000000e+06
# Iter    1 | Loss = 6.651370e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 9.790023e+05, target fluence: 1.000000e+06
# Iter    2 | Loss = 6.474648e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 9.719028e+05, target fluence: 1.000000e+06
# Iter    3 | Loss = 6.297285e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 9.666121e+05, target fluence: 1.000000e+06
# Iter    4 | Loss = 6.116277e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 9.629956e+05, target fluence: 1.000000e+06
# Iter    5 | Loss = 5.930424e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 9.609976e+05, target fluence: 1.000000e+06
# Iter    6 | Loss = 5.739731e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 9.605951e+05, target fluence: 1.000000e+06
# Iter    7 | Loss = 5.544670e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 9.617817e+05, target fluence: 1.000000e+06
# Iter    8 | Loss = 5.345956e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 9.645485e+05, target fluence: 1.000000e+06
# Iter    9 | Loss = 5.144418e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 9.688981e+05, target fluence: 1.000000e+06
# Iter   10 | Loss = 4.941058e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 9.748419e+05, target fluence: 1.000000e+06
# Iter   11 | Loss = 4.737022e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 9.823904e+05, target fluence: 1.000000e+06
# Iter   12 | Loss = 4.533519e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 9.915498e+05, target fluence: 1.000000e+06
# Iter   13 | Loss = 4.331775e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.002315e+06, target fluence: 1.000000e+06
# Iter   14 | Loss = 4.132992e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.014665e+06, target fluence: 1.000000e+06
# Iter   15 | Loss = 3.938317e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.028555e+06, target fluence: 1.000000e+06
# Iter   16 | Loss = 3.748804e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.043916e+06, target fluence: 1.000000e+06
# Iter   17 | Loss = 3.565391e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.060650e+06, target fluence: 1.000000e+06
# Iter   18 | Loss = 3.388869e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.078629e+06, target fluence: 1.000000e+06
# Iter   19 | Loss = 3.219867e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.097697e+06, target fluence: 1.000000e+06
# [0.1, 0.3]
# Iter   20 | Loss = 3.058842e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.117676e+06, target fluence: 1.000000e+06
# Iter   21 | Loss = 2.906096e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.138366e+06, target fluence: 1.000000e+06
# Iter   22 | Loss = 2.761789e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.159556e+06, target fluence: 1.000000e+06
# Iter   23 | Loss = 2.625953e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.181024e+06, target fluence: 1.000000e+06
# Iter   24 | Loss = 2.498514e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.202543e+06, target fluence: 1.000000e+06
# Iter   25 | Loss = 2.379302e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.223880e+06, target fluence: 1.000000e+06
# Iter   26 | Loss = 2.268063e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.244805e+06, target fluence: 1.000000e+06
# Iter   27 | Loss = 2.164473e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.265092e+06, target fluence: 1.000000e+06
# Iter   28 | Loss = 2.068151e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.284519e+06, target fluence: 1.000000e+06
# Iter   29 | Loss = 1.978668e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.302881e+06, target fluence: 1.000000e+06
# Iter   30 | Loss = 1.895560e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.319985e+06, target fluence: 1.000000e+06
# Iter   31 | Loss = 1.818344e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.335660e+06, target fluence: 1.000000e+06
# Iter   32 | Loss = 1.746528e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.349756e+06, target fluence: 1.000000e+06
# Iter   33 | Loss = 1.679620e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.362147e+06, target fluence: 1.000000e+06
# Iter   34 | Loss = 1.617141e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.372736e+06, target fluence: 1.000000e+06
# Iter   35 | Loss = 1.558633e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.381452e+06, target fluence: 1.000000e+06
# Iter   36 | Loss = 1.503666e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.388254e+06, target fluence: 1.000000e+06
# Iter   37 | Loss = 1.451841e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.393128e+06, target fluence: 1.000000e+06
# Iter   38 | Loss = 1.402796e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.396087e+06, target fluence: 1.000000e+06
# Iter   39 | Loss = 1.356207e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.397172e+06, target fluence: 1.000000e+06
# [0.1, 0.3]
# Iter   40 | Loss = 1.311787e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.396448e+06, target fluence: 1.000000e+06
# Iter   41 | Loss = 1.269287e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.394000e+06, target fluence: 1.000000e+06
# Iter   42 | Loss = 1.228492e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.389933e+06, target fluence: 1.000000e+06
# Iter   43 | Loss = 1.189223e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.384368e+06, target fluence: 1.000000e+06
# Iter   44 | Loss = 1.151332e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.377439e+06, target fluence: 1.000000e+06
# Iter   45 | Loss = 1.114697e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.369289e+06, target fluence: 1.000000e+06
# Iter   46 | Loss = 1.079224e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.360067e+06, target fluence: 1.000000e+06
# Iter   47 | Loss = 1.044841e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.349927e+06, target fluence: 1.000000e+06
# Iter   48 | Loss = 1.011493e+01 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.339023e+06, target fluence: 1.000000e+06
# Iter   49 | Loss = 9.791401e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.327506e+06, target fluence: 1.000000e+06
# Iter   50 | Loss = 9.477549e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.315524e+06, target fluence: 1.000000e+06
# Iter   51 | Loss = 9.173166e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.303220e+06, target fluence: 1.000000e+06
# Iter   52 | Loss = 8.878102e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.290723e+06, target fluence: 1.000000e+06
# Iter   53 | Loss = 8.592230e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.278160e+06, target fluence: 1.000000e+06
# Iter   54 | Loss = 8.315424e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.265640e+06, target fluence: 1.000000e+06
# Iter   55 | Loss = 8.047549e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.253266e+06, target fluence: 1.000000e+06
# Iter   56 | Loss = 7.788445e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.241125e+06, target fluence: 1.000000e+06
# Iter   57 | Loss = 7.537920e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.229294e+06, target fluence: 1.000000e+06
# Iter   58 | Loss = 7.295755e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.217837e+06, target fluence: 1.000000e+06
# Iter   59 | Loss = 7.061694e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.206809e+06, target fluence: 1.000000e+06
# [0.1, 0.3]
# Iter   60 | Loss = 6.835462e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.206809e+06, target fluence: 1.000000e+06
# Iter   61 | Loss = 6.750890e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.206809e+06, target fluence: 1.000000e+06
# Iter   62 | Loss = 6.707817e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.206809e+06, target fluence: 1.000000e+06
# Iter   63 | Loss = 6.683381e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.206809e+06, target fluence: 1.000000e+06
# Iter   64 | Loss = 6.664840e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.206809e+06, target fluence: 1.000000e+06
# Iter   65 | Loss = 6.649279e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.206809e+06, target fluence: 1.000000e+06
# Iter   66 | Loss = 6.637393e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.206809e+06, target fluence: 1.000000e+06
# Iter   67 | Loss = 6.629215e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.206809e+06, target fluence: 1.000000e+06
# Iter   68 | Loss = 6.623758e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.206809e+06, target fluence: 1.000000e+06
# Iter   69 | Loss = 6.620042e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.206809e+06, target fluence: 1.000000e+06
# Iter   70 | Loss = 6.617497e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.206809e+06, target fluence: 1.000000e+06
# Iter   71 | Loss = 6.615732e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.206809e+06, target fluence: 1.000000e+06
# Iter   72 | Loss = 6.614389e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.206809e+06, target fluence: 1.000000e+06
# Iter   73 | Loss = 6.613217e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.206809e+06, target fluence: 1.000000e+06
# Iter   74 | Loss = 6.612107e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.206809e+06, target fluence: 1.000000e+06
# Iter   75 | Loss = 6.611040e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.206809e+06, target fluence: 1.000000e+06
# Iter   76 | Loss = 6.610027e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.206809e+06, target fluence: 1.000000e+06
# Iter   77 | Loss = 6.609079e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.206809e+06, target fluence: 1.000000e+06
# Iter   78 | Loss = 6.608208e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.206809e+06, target fluence: 1.000000e+06
# Iter   79 | Loss = 6.607421e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.206809e+06, target fluence: 1.000000e+06
# [0.05, 0.15]
# Iter   80 | Loss = 6.606724e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.206809e+06, target fluence: 1.000000e+06
# Iter   81 | Loss = 6.606377e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.206809e+06, target fluence: 1.000000e+06
# Iter   82 | Loss = 6.606003e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.206809e+06, target fluence: 1.000000e+06
# Iter   83 | Loss = 6.605612e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.206809e+06, target fluence: 1.000000e+06
# Iter   84 | Loss = 6.605223e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.206809e+06, target fluence: 1.000000e+06
# Iter   85 | Loss = 6.604846e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.206809e+06, target fluence: 1.000000e+06
# Iter   86 | Loss = 6.604492e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.206809e+06, target fluence: 1.000000e+06
# Iter   87 | Loss = 6.604161e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.206809e+06, target fluence: 1.000000e+06
# Iter   88 | Loss = 6.603858e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.206809e+06, target fluence: 1.000000e+06
# Iter   89 | Loss = 6.603713e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.206809e+06, target fluence: 1.000000e+06
# Iter   90 | Loss = 6.603568e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.206809e+06, target fluence: 1.000000e+06
# Iter   91 | Loss = 6.603424e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.206809e+06, target fluence: 1.000000e+06
# Iter   92 | Loss = 6.603285e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.206809e+06, target fluence: 1.000000e+06
# Iter   93 | Loss = 6.603147e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.206809e+06, target fluence: 1.000000e+06
# Iter   94 | Loss = 6.603016e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.206809e+06, target fluence: 1.000000e+06
# Iter   95 | Loss = 6.602952e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.206809e+06, target fluence: 1.000000e+06
# Iter   96 | Loss = 6.602888e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.206809e+06, target fluence: 1.000000e+06
# Iter   97 | Loss = 6.602824e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.206809e+06, target fluence: 1.000000e+06
# Iter   98 | Loss = 6.602760e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.206809e+06, target fluence: 1.000000e+06
# Iter   99 | Loss = 6.602698e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.206809e+06, target fluence: 1.000000e+06
# [0.00625, 0.01875]
# Iter  100 | Loss = 6.602637e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.206142e+06, target fluence: 1.000000e+06
# Iter  101 | Loss = 6.589153e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.205489e+06, target fluence: 1.000000e+06
# Iter  102 | Loss = 6.575747e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.204849e+06, target fluence: 1.000000e+06
# Iter  103 | Loss = 6.562411e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.204222e+06, target fluence: 1.000000e+06
# Iter  104 | Loss = 6.549138e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.203606e+06, target fluence: 1.000000e+06
# Iter  105 | Loss = 6.535921e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.203001e+06, target fluence: 1.000000e+06
# Iter  106 | Loss = 6.522754e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.202406e+06, target fluence: 1.000000e+06
# Iter  107 | Loss = 6.509634e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.201821e+06, target fluence: 1.000000e+06
# Iter  108 | Loss = 6.496555e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.201244e+06, target fluence: 1.000000e+06
# Iter  109 | Loss = 6.483517e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.200676e+06, target fluence: 1.000000e+06
# Iter  110 | Loss = 6.470514e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.200115e+06, target fluence: 1.000000e+06
# Iter  111 | Loss = 6.457544e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.199562e+06, target fluence: 1.000000e+06
# Iter  112 | Loss = 6.444607e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.199016e+06, target fluence: 1.000000e+06
# Iter  113 | Loss = 6.431699e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.198476e+06, target fluence: 1.000000e+06
# Iter  114 | Loss = 6.418819e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.197943e+06, target fluence: 1.000000e+06
# Iter  115 | Loss = 6.405965e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.197415e+06, target fluence: 1.000000e+06
# Iter  116 | Loss = 6.393137e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.196893e+06, target fluence: 1.000000e+06
# Iter  117 | Loss = 6.380334e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.196376e+06, target fluence: 1.000000e+06
# Iter  118 | Loss = 6.367554e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.195864e+06, target fluence: 1.000000e+06
# Iter  119 | Loss = 6.354796e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j
# Calculated fluence from probe amplitude: 1.195357e+06, target fluence: 1.000000e+06
# [0.00625, 0.01875]
# Iter  120 | Loss = 6.342061e+00 | C, A1, A2: 5.000000e+01+5.000000e+01j, 1.000000e+00+3.000000e+00j, 5.000000e+00+2.000000e+00j

# %% [markdown]
# ## Loop through a few different hyperparameters

# %%
import itertools
import pickle
import os

# Initial probe and object
initial_theta = torch.nn.Parameter(torch.rand((H, W), device=device) * 0.01 + torch.pi/2)
initial_phi   = torch.nn.Parameter(torch.rand((H, W), device=device) * 0.1 + torch.pi/2)

P_test = torch.zeros_like(R)
Diffuser = torch.rand((H, W), device=device)
P_test = torch.exp(2j*np.pi*Diffuser)*(torch.exp(-0.8*R))
initial_probe_amplitude = P_test


# --- hyperparameter ranges ---
gradient_pf_list = [1.0, 1e-1, 1e-1]
anisotropy_pf_list = [1.0, 1e-1, 1e-1]

base_loss_prefactors = {
    'sqrt_amp_pf': 1.0,
}

optimizer_params = {
    'theta_lr': 5e-1,
    'phi_lr': 5e-1,
    'CA_lr': 1e-5,
    'probe_lr': 60e-1
}

output_dir = "hyperparam_runs"
os.makedirs(output_dir, exist_ok=True)

# --- loop ---
for gradient_pf, anisotropy_pf in itertools.product(gradient_pf_list, anisotropy_pf_list):
    
    loss_prefactors = {
        **base_loss_prefactors,
        'gradient_pf': gradient_pf,
        'anisotropy_pf': anisotropy_pf
    }
    
    run_name = f"grad_{gradient_pf:.0e}_anis_{anisotropy_pf:.0e}"
    
    plot_filename = os.path.join(output_dir, f"plot_{run_name}.png")
    pickle_filename = os.path.join(output_dir, f"result_{run_name}.pkl")
    
    print(f"Running: {run_name}")
    
    result = optimize_object_and_probe_with_scheduler(
        scan, pol_angles, I_sim, H, W,
        initial_theta=initial_theta,
        initial_phi=initial_phi,
        initial_probe_amplitude=initial_probe_amplitude,
        num_iterations=80,
        device=device,
        loss_prefactors=loss_prefactors,
        plot_filename=plot_filename
    )
    
    # optional: include params explicitly in saved object
    result_to_save = {
        "run_name": run_name,
        "gradient_pf": gradient_pf,
        "anisotropy_pf": anisotropy_pf,
        "result": result
    }
    
    # save immediately
    with open(pickle_filename, "wb") as f:
        pickle.dump(result_to_save, f)

    print(f"Saved: {pickle_filename}")

# %%
import os
import pickle
import glob
import matplotlib.pyplot as plt

results_dir = "hyperparam_runs"

# find all pickle files
pickle_files = sorted(glob.glob(os.path.join(results_dir, "result_*.pkl")))

plt.figure()

for pf in pickle_files:
    with open(pf, "rb") as f:
        data = pickle.load(f)
    
    run_name = data["run_name"]
    loss_history = data["result"]["loss_history"]
    
    plt.plot(loss_history, label=run_name)

plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.yscale("log")
plt.title("Loss history for different hyperparameters")

# optional: legend can get crowded
plt.legend(fontsize=8)
plt.tight_layout()
plt.show()

# %%
plot_probe_maps(result["probe_amplitude"].detach().cpu().numpy(), Lx, Ly)
plot_theta_phi_maps(
    result["theta"].detach().cpu().numpy(),
    result["phi"].detach().cpu().numpy(),
    Lx,
    Ly,
    theta_cmap='magma',
    phi_cmap=RGB_scale,
    label_axes=True,
)

# %%
plt.plot(result["loss_history"])
plt.ylabel('Loss')
plt.xlabel('Iteration')
plt.yscale('log')
plt.show()
