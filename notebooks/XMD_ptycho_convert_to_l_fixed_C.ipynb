# %% [markdown]
# # Updating probe and object
# ## Using Mx, My, Mz rather than polar angles and normalising after every iteration.
# ## Now keeping C, A1, A2 fixed.

# %%
import importlib
import vector_ptycho.utils as vpu
importlib.reload(vpu)
from vector_ptycho.utils import *
import numpy as np
import matplotlib.pyplot as plt
import torch
import pickle
from IPython.display import display
from vector_ptycho.utils import _to_numpy

# %%
RGB_scale = make_vector_color_map(plot=False)

# %% [markdown]
# ## Define the object, probe, fluence and XMLD constants

# %%
H, W = 100, 100
Lx = 5
Ly = 5

# Build theta, phi from meron-antimeron generator (returns torch tensors)
theta, phi, Mx, My, Mz = make_meron_antimeron_theta_phi(
    Nx=W,
    Ny=H,
    Lx=Lx,
    Ly=Ly,
    plot=False,
    save_path=None,
    export_path=None,
    return_torch=True,
    out_device=device,
    cm = RGB_scale,
)

# Physical XMLD/Jones constants
C = torch.tensor(50.0+ 5.0j, dtype=cdtype, device=device)
A1 = torch.tensor(1 + 300j, dtype=cdtype, device=device)
A2 = torch.tensor(5 + 2j, dtype=cdtype, device=device)

# Build Jones object from theta, phi
neel = NeelObject(C, A1, A2)
J = neel.build_jones(theta, phi)
obj = JonesObject(J)

# Grid for probe definition
x = torch.linspace(-Lx, Lx, H, device=device)
y = torch.linspace(-Ly, Ly, W, device=device)
X, Y = torch.meshgrid(x, y, indexing='ij')

# Define a probe with some phase structure on the wavefront.
fluence = torch.scalar_tensor(1e6, dtype=torch.float64, device=device)
R=torch.sqrt(X**2+Y**2) #This helps with defining the probe
R_probe = 1.0
Diffuser = 0.1*(torch.sin(1*R)+torch.cos((Y*5+X*1)-0.8*(X-0.2))+torch.cos((Y-X)-0.4*(X)))*(R<R_probe) #(torch.sqrt(3*X**2+1.5*Y**2)+torch.pi/3)#*(torch.exp(-0.1*R)) #np.mod(0.1*(torch.sin(150*R)+torch.cos((Y*10+X*30)**2-0.8*(X*75-0.2))+torch.cos((Y*10-X*33)**2-0.4*(X*50-0.2))),1)
P = torch.zeros_like(R)
P = torch.exp(2j*np.pi*Diffuser)*(R<R_probe)#*(torch.exp(-0.8*R))

# Calculate the Jones vectors of the probes for different Linear polarisation states
probes = []
pol_angles = [0, 30, 60, 90]#, 120, 150, 180]
for angle in pol_angles:
    rad = np.deg2rad(angle)
    jones_vec = torch.tensor([np.cos(rad) + 0j, np.sin(rad) + 0j], dtype=cdtype, device=device)
    print(f'Jones vector for {angle} deg linear polarisation: {jones_vec}')
    probes.append(Probe(P, jones_vec, fluence=fluence, normalized=False))

print('Defined {} probes with different linear polarisation states.'.format(len(probes)))


plot_probe_maps(probes[0].amplitude, Lx, Ly)
print('Probe fluence:', probes[0].fluence)
# Out:
# Jones vector for 0 deg linear polarisation: tensor([1.+0.j, 0.+0.j])
# Jones vector for 30 deg linear polarisation: tensor([0.8660+0.j, 0.5000+0.j])
# Jones vector for 60 deg linear polarisation: tensor([0.5000+0.j, 0.8660+0.j])
# Jones vector for 90 deg linear polarisation: tensor([6.1232e-17+0.j, 1.0000e+00+0.j])
# Defined 4 probes with different linear polarisation states.
# Probe fluence: tensor(1000000., dtype=torch.float64)

# %% [markdown]
# # Define the scan trajectory, simulate the detector

# %%
xshiftvec = torch.linspace(-2.5, 2.5,6)
yshiftvec = torch.linspace(-2.5, 2.5,6)

# Shifting the text so that we can plot on the data
dx = (xshiftvec[1] - xshiftvec[0]) / 10
dy = (yshiftvec[1] - yshiftvec[0]) / 10

# Lab-coordinate scan grid used for plotting
xpos_lab, ypos_lab = torch.meshgrid(xshiftvec, yshiftvec, indexing="ij")
positions = torch.stack([ypos_lab.flatten(), xpos_lab.flatten()], dim=1)

# Convert lab coordinates into discrete pixel shifts for torch.roll(row, col)
pixel_size_y = (2 * Ly) / (H - 1)
pixel_size_x = (2 * Lx) / (W - 1)
positions_idx = torch.stack([
    torch.round(positions[:, 0] / pixel_size_y),
    torch.round(positions[:, 1] / pixel_size_x),
], dim=1).to(torch.int64)

scan = ScanTrajectory(positions_idx)

# Forward model
model = ForwardModel(obj, Propagator(), Detector(add_poisson_noise=True))
I_sim = model.simulate_all(probes, scan)
print('Simulated data shape:', I_sim.shape)  # (N_probes, N_positions, H, W)
# Out:
# C:\Users\godfrey\OneDrive - Nexus365\Documents\Google Drive (old computer 12_07_2022)\PhD\Year 3\Term 1\Ptycho\vector-ptycho\src\vector_ptycho\utils.py:483: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.positions = torch.tensor(positions, device=device)
# Simulated data shape: torch.Size([4, 36, 100, 100])

# %%
plot_theta_phi_maps(theta, phi, Lx, Ly,theta_cmap='magma',
                       phi_cmap=RGB_scale,
                       positions=positions, dx=0.3, dy=0.3, show_positions=True, label_positions=True, label_axes=True)
# Out:
# (<Figure size 1200x500 with 4 Axes>,
#  array([<Axes: title={'center': '$l_z$ heatmap'}, xlabel='$x$ [m]', ylabel='$y$ [m]'>,
#         <Axes: title={'center': '$\\phi$ heatmap'}, xlabel='$x$ [m]', ylabel='$y$ [m]'>],
#        dtype=object))

# %%
# Normalise I_sim for the autograd - divide by the mean to keep values around 1, which helps with the gradients - now l has a magnitude of 1, probe and detector have values around 1, so the gradients are nicely balanced and we don't have to worry about vanishing or exploding gradients as much.
I_sim_norm = I_sim / I_sim.mean()

# %%
fig, axes = plt.subplots(4, 4, figsize=(12, 12))

#scan_indices = [35, 36, 45, 43]
scan_indices = [1, 2, 20, 24]
probe_numbers = [0, 1, 2, 3]

for i, probe_number in enumerate(probe_numbers):      # rows
    for j, scan_idx in enumerate(scan_indices):       # columns
        
        axes[i, j].imshow(
            ((I_sim[probe_number, scan_idx].cpu()+1e-8)),
            cmap='inferno'
        )
        
        '''
        axes[i, j].imshow(
            np.log10(I_sim[probe_number, scan_idx].cpu()+1e-8),
            cmap='inferno',
        )
        '''
        axes[i, j].set_title(f'Probe {probe_number}, Pos {scan_idx}, x={positions[scan_idx, 0].item():.2f}, y={positions[scan_idx, 1].item():.2f}')
        axes[i, j].axis('off')

plt.tight_layout()
plt.show()

# %%
def normalise_neel(l):
    # Normalize to ensure L is always a unit vector
    mag = torch.sqrt(torch.sum(l**2, dim=0) + 1e-8)
    Lx = l[0] / mag
    Ly = l[1] / mag
    Lz = l[2] / mag
    return Lx, Ly, Lz

def optimize_object(scan, pol_angles, I_meas, H, W, initial_l, initial_probe_amplitude,num_iterations=100, device=None,
                                             optimizer_params={'l_lr': 1e-1, 'CA_lr': 1e-5},
                                             plot_filename=None):
    """
    Reconstruct probes (different for each polarisation) l C, A1, A2 from measured diffraction patterns.
    This is different to previous versions because it directly updates lx, ly, lz to avoid differentiation problems associated with angular coordinates.
    .
    Parameters
    ----------
    scan : ScanTrajectory
        Scan positions.
    pol_angles : list of float
        List of polarisation angles in degrees for each probe.
    I_meas : torch.Tensor
        Measured diffraction intensities, shape (N_probes, N_scan, Hdet, Wdet)
    H, W : int
        Object map size.
    initial_l : torch.Tensor
        Initial guess for the neel vector in Cartesian coordinates, shape (3, H, W).
    initial_probe_amplitude : torch.Tensor
        Initial guess for the probe amplitude, shape (H, W).
    num_iterations : int
        Number of optimization steps.
    device : torch.device or str
        Device to use.
    loss_prefactors : dict
        Prefactors for different loss components - how much to weight anisotropy and gradient losses relative to the amplitude loss.
    optimizer_params : dict
        Learning rates for different parameter groups in the optimizer.
    plot_filename : str or None
        If not None, save intermediate plots to this filename during optimization.
     Returns
    -------
    dict
        Reconstructed parameters and loss history.
    """
    if device is None:
        device = I_meas.device

    # This is for the live plot updates
    plot_update = create_live_plotter(Lx, Ly, phi_cmap=RGB_scale, theta_cmap='magma')

    eps = 1e-12
    cdtype = torch.complex64

    # Learnable parameters

    l = torch.nn.Parameter(initial_l) # Defining the neel vector in terms of it's lx, ly, lz components, which are then normalised to get theta and phi. This is easier to optimise than directly optimising theta and phi, which have singularities at the poles.
    probe_amplitude = initial_probe_amplitude

    # Initialise the probe array (same for all pol states at the moment)
    probes = []
    for angle in pol_angles:
        rad = np.deg2rad(angle)
        jones_vec = torch.tensor([np.cos(rad) + 0j, np.sin(rad) + 0j], dtype=cdtype, device=device)
        probes.append(Probe(probe_amplitude, jones_vec, fluence=fluence, normalized=False))
    probe_amplitude = (probes[0].amplitude) #It has now been normalised to the correct fluence.
    probe_amplitude_start = probes[0].amplitude
    fluence_calc = torch.sum(torch.abs(probe_amplitude_start)**2)
    print(f"Calculated initial fluence from probe amplitude: {fluence_calc.item():.6e}, target fluence: {fluence.item():.6e}")

    optimizer = torch.optim.AdamW([
        {"params": [l], "lr": optimizer_params['l_lr']},
        {"params": [C, A1, A2], "lr": optimizer_params['CA_lr']}
        ])
    
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer,
        mode='min',
        factor=0.5,       # reduce LR by 2x
        patience=5,      # wait 5 iterations without improvement
        threshold=1e-3,   # minimum change to count as improvement
        min_lr=1e-6,      # don't go too small
    )
    loss_history = []

    for iteration in range(num_iterations):
        optimizer.zero_grad(set_to_none=True)

        l_mag = torch.sqrt(torch.sum(l**2, dim=0) + 1e-8) 
        
        # Create normalized Cartesian components
        lx_norm = l[0] / l_mag
        ly_norm = l[1] / l_mag
        lz_norm = l[2] / l_mag

        # Build Jones object from current parameters
        neel = NeelObject(C, A1, A2)
        J = neel.build_jones_from_cartesian(lx= lx_norm, ly=ly_norm, lz=lz_norm)
        obj = JonesObject(J)

        # Remake the probe array
        probes = []
        for angle in pol_angles:
            rad = np.deg2rad(angle)
            jones_vec = torch.tensor([np.cos(rad) + 0j, np.sin(rad) + 0j], dtype=cdtype, device=device)
            probes.append(Probe(probe_amplitude, jones_vec, fluence=fluence, normalized=True))

        # Forward model
        model = ForwardModel(obj, Propagator(), Detector())
        I_pred = model.simulate_all(probes, scan)
        eps = 1e-8

        fluence_calc = torch.sum(torch.abs(probe_amplitude)**2)
        print(f"Calculated fluence from probe amplitude: {fluence_calc.item():.6e}, target fluence: {fluence.item():.6e}")

        # Define the loss function
        loss = torch.mean((torch.sqrt(I_pred + eps) - torch.sqrt(I_meas + eps))**2)

        loss.backward()
        optimizer.step()

        # Step the scheduler with the current loss
        scheduler.step(loss)

        if iteration % 20 == 0:
            print([group['lr'] for group in optimizer.param_groups])

        loss_history.append(loss.item())

        if iteration % 1 == 0:
            theta = torch.acos(lz_norm)
            phi = torch.atan2(ly_norm, lx_norm)
            l_mag = torch.sqrt(torch.sum(l**2, dim=0) + 1e-8)
            print(f"Iter {iteration:4d} | Loss = {loss.item():.6e}")
            plot_update(probe_amplitude, theta, phi, loss, save_filename=plot_filename)

    return {
        "l": l.detach(),
        "probe_amplitude": probe_amplitude.detach(),
        "C": C.detach(),
        "A1": A1.detach(),
        "A2": A2.detach(),
        "loss_history": loss_history,
        "optimizer_params": optimizer_params  
    }

'''
initial_l = torch.stack([
    torch.randn(H, W, device=device)*0.1,
    torch.randn(H, W, device=device)*1,
    torch.randn(H, W, device=device)*0.1
])
'''
initial_l = torch.randn(3, H, W, device=device)
result = optimize_object(scan, pol_angles, I_sim, H, W,
                                initial_probe_amplitude=P,
                                initial_l=initial_l,
                                num_iterations=5, device=device)
# Out:
# Calculated initial fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# [0.1, 1e-05]
# Iter    0 | Loss = 1.849511e+02
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter    1 | Loss = 1.594141e+02
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter    2 | Loss = 1.356028e+02
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter    3 | Loss = 1.147985e+02
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter    4 | Loss = 9.704302e+01

# %%
def normalise_neel(l):
    # Normalize to ensure L is always a unit vector
    mag = torch.sqrt(torch.sum(l**2, dim=0) + 1e-8)
    Lx = l[0] / mag
    Ly = l[1] / mag
    Lz = l[2] / mag
    return Lx, Ly, Lz

def optimize_object_and_probe_with_scheduler(scan, pol_angles, I_meas, H, W, initial_l, initial_probe_amplitude,num_iterations=100, device=None, 
                                             loss_prefactors={'sqrt_amp_pf': 1.0, 'gradient_pf': 1e-4, 'anisotropy_pf': 1e-4, 'probe_localisation_pf': 1e-3},
                                             optimizer_params={'l_lr': 1e-3, 'CA_lr': 1e-5, 'probe_lr': 60e-1},
                                             plot_filename=None, object_randomisation=False, probe_randomisation=False):
    """
    Reconstruct probes (different for each polarisation) l C, A1, A2 from measured diffraction patterns.
    This is different to previous versions because it directly updates lx, ly, lz to avoid differentiation problems associated with angular coordinates.
    .
    Parameters
    ----------
    scan : ScanTrajectory
        Scan positions.
    pol_angles : list of float
        List of polarisation angles in degrees for each probe.
    I_meas : torch.Tensor
        Measured diffraction intensities, shape (N_probes, N_scan, Hdet, Wdet)
    H, W : int
        Object map size.
    initial_l : torch.Tensor
        Initial guess for the neel vector in Cartesian coordinates, shape (3, H, W).
    initial_probe_amplitude : torch.Tensor
        Initial guess for the probe amplitude, shape (H, W).
    num_iterations : int
        Number of optimization steps.
    device : torch.device or str
        Device to use.
    loss_prefactors : dict
        Prefactors for different loss components - how much to weight anisotropy and gradient losses relative to the amplitude loss.
    optimizer_params : dict
        Learning rates for different parameter groups in the optimizer.
    plot_filename : str or None
        If not None, save intermediate plots to this filename during optimization.
    object_randomisation : bool
        Whether to apply randomisation to the object parameters during optimization to help escape local minima.
    probe_randomisation : bool
        Whether to apply randomisation to the probe parameters during optimization to help escape local minima.
     Returns
    -------
    dict
        Reconstructed parameters and loss history.
    """
    if device is None:
        device = I_meas.device

    # This is for the live plot updates
    plot_update = create_live_plotter(Lx, Ly, phi_cmap=RGB_scale, theta_cmap='magma')

    eps = 1e-6
    cdtype = torch.complex64

    # Learnable parameters

    l = torch.nn.Parameter(initial_l) # Defining the neel vector in terms of it's lx, ly, lz components, which are then normalised to get theta and phi. This is easier to optimise than directly optimising theta and phi, which have singularities at the poles.
    probe_amplitude = initial_probe_amplitude

    # Initialise the probe array (same for all pol states at the moment)
    probes = []
    for angle in pol_angles:
        rad = np.deg2rad(angle)
        jones_vec = torch.tensor([np.cos(rad) + 0j, np.sin(rad) + 0j], dtype=cdtype, device=device)
        probes.append(Probe(probe_amplitude, jones_vec, fluence=fluence, normalized=False))
    probe_amplitude = torch.nn.Parameter(probes[0].amplitude) #It has now been normalised to the correct fluence.
    probe_amplitude_start = probes[0].amplitude
    fluence_calc = torch.sum(torch.abs(probe_amplitude_start)**2)
    print(f"Calculated initial fluence from probe amplitude: {fluence_calc.item():.6e}, target fluence: {fluence.item():.6e}")

    optimizer = torch.optim.AdamW([
        {"params": [l], "lr": optimizer_params['l_lr']}, #{"params": [C, A1, A2], "lr": optimizer_params['CA_lr']},
        {"params": [probe_amplitude], "lr": optimizer_params['probe_lr']}
        ])
    
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer,
        mode='min',
        factor=0.5,       # reduce LR by 2x
        patience=500,      # wait 5 iterations without improvement
        threshold=1e-3,   # minimum change to count as improvement
        min_lr=1e-6,      # don't go too small
    )
    loss_history = []

    for iteration in range(num_iterations):
        
        if iteration < 60:
            for p in [l, C, A1, A2]:
                p.requires_grad_(True)
            probe_amplitude.requires_grad_(False)
            print('Free object parameters, fixing probe amplitude.')
        if iteration >= 60 and iteration < 100:
            for p in [l, C, A1, A2]:
                p.requires_grad_(False)
            probe_amplitude.requires_grad_(True)
            print('Free probe, fixed object')
        if iteration >= 100:
            for p in [l, C, A1, A2]:
                p.requires_grad_(True)
            probe_amplitude.requires_grad_(True)
            print('Optimizing all parameters.')
        
        optimizer.zero_grad(set_to_none=True)

        l_mag = torch.sqrt(torch.sum(l**2, dim=0) + 1e-8) 
        
        # Create normalized Cartesian components
        lx_norm = l[0] / l_mag
        ly_norm = l[1] / l_mag
        lz_norm = l[2] / l_mag

        # Build Jones object from current parameters
        neel = NeelObject(C, A1, A2)
        J = neel.build_jones_from_cartesian(lx= lx_norm, ly=ly_norm, lz=lz_norm)
        obj = JonesObject(J)

        # Remake the probe array
        probes = []
        for angle in pol_angles:
            rad = np.deg2rad(angle)
            jones_vec = torch.tensor([np.cos(rad) + 0j, np.sin(rad) + 0j], dtype=cdtype, device=device)
            probes.append(Probe(probe_amplitude, jones_vec, fluence=fluence, normalized=True))

        # Forward model
        model = ForwardModel(obj, Propagator(), Detector())
        I_pred = model.simulate_all(probes, scan)
        I_pred_safe = torch.clamp(I_pred, min=0.0)
        

        fluence_calc = torch.sum(torch.abs(probe_amplitude)**2)
        print(f"Calculated fluence from probe amplitude: {fluence_calc.item():.6e}, target fluence: {fluence.item():.6e}")
        '''
        if loss_prefactors['gradient_pf'] > 0 or loss_prefactors['anisotropy_pf'] > 0:
            #Only perform this computation if the prefactors are > 0, as it is quite expensive.

            # 2. Compute spatial gradients using finite differences
            # Differences along the X-axis (width)
            dx_lx = torch.diff(lx_norm, dim=-1)
            dx_ly = torch.diff(ly_norm, dim=-1)
            dx_lz = torch.diff(lz_norm, dim=-1)

            # Differences along the Y-axis (height)
            dy_lx = torch.diff(lx_norm, dim=-2)
            dy_ly = torch.diff(ly_norm, dim=-2)
            dy_lz = torch.diff(lz_norm, dim=-2)

            grad_mag_x = torch.sqrt(dx_lx**2 + dx_ly**2 + dx_lz**2 + 1e-8) # 1e-8 prevents NaN in sqrt at 0
            grad_mag_y = torch.sqrt(dy_lx**2 + dy_ly**2 + dy_lz**2 + 1e-8)

            loss_x = torch.sum(grad_mag_x**2)
            loss_y = torch.sum(grad_mag_y**2)

            gradient_loss = loss_x + loss_y
            anisotropy_loss = torch.sum(l[2]**2) # Positive prefactor will favour IP alignment.
        else:
            gradient_loss = 0.0
            anisotropy_loss = 0.0
        '''
        '''
        # Amplitude-based ptychographic loss
        if loss_prefactors['probe_localisation_pf'] > 0:
            probe_localisation_loss = loss_prefactors['probe_localisation_pf'] * torch.mean(torch.abs(probe_amplitude)**2*R**2) #This stops the probe from drifting by penalising amplitude at large R
        else:
            probe_localisation_loss = 0.0
        '''
        # Define the loss function
        loss = loss_prefactors['sqrt_amp_pf'] * torch.mean((torch.sqrt(I_pred_safe + eps) - torch.sqrt(I_meas + eps))**2) #+ loss_prefactors['gradient_pf'] * gradient_loss + loss_prefactors['anisotropy_pf'] * anisotropy_loss + probe_localisation_loss
        #loss = loss + loss_prefactors['STXM_pf']*(torch.sqrt(torch.sum(I_pred_safe + eps) - torch.sqrt(torch.sum(I_meas + eps)))**2) # This is a simple loss term to try to match the total intensity, which can help with convergence when the probe is also being optimised.
        # Loop over each diffraction pattern and measure the difference in the total intensity transmitted
        for pos in range(len(scan.positions)):
            for pol in range(len(pol_angles)):
                loss = loss+loss_prefactors['STXM_pf']*(torch.sqrt(torch.sum(I_pred_safe[pol, pos, :,:] + eps)) - torch.sqrt(torch.sum(I_meas[pol, pos, :,:] + eps)))**2
        loss.backward()
        optimizer.step()

        # Step the scheduler with the current loss
        scheduler.step(loss)

        if iteration % 20 == 0:
            print([group['lr'] for group in optimizer.param_groups])
        
        if iteration % 8 == 0 and iteration < 30:
            with torch.no_grad():
                if probe_randomisation:
                    probe_amplitude.data += (torch.rand((H, W), device=device) * torch.max(torch.abs(probe_amplitude))*0.25)
                if object_randomisation:
                    for i in range(3):
                        noise = torch.randn_like(l[i])
                        l[i] += 1.5 * noise

        loss_history.append(loss.item())

        if iteration % 1 == 0:
            theta = torch.acos(torch.clamp(lz_norm, -1.0 + 1e-6, 1.0 - 1e-6)) # Clamp to avoid NaNs from acos outside of [-1, 1]
            phi = torch.atan2(ly_norm, lx_norm)
            l_mag = torch.sqrt(torch.sum(l**2, dim=0) + eps)
            print(f"Iter {iteration:4d} | Loss = {loss.item():.6e} | C, A1, A2: {C.item():.6e}, {A1.item():.6e}, {A2.item():.6e}")
            plot_update(probe_amplitude, theta, phi, loss, save_filename=plot_filename)

    return {
        "l": l.detach(),
        "probe_amplitude": probe_amplitude.detach(),
        "C": C.detach(),
        "A1": A1.detach(),
        "A2": A2.detach(),
        "loss_history": loss_history,
        "optimizer_params": optimizer_params,
        "loss_prefactors": loss_prefactors,   
    }

# %%
#initial_l = torch.randn(3, H, W, device=device)

initial_l = torch.stack([
    torch.randn(H, W, device=device)*0.1,
    torch.randn(H, W, device=device)*1,
    torch.randn(H, W, device=device)*0.1
])

Diffuser = 0.1*(torch.sin(1*R)+torch.cos((Y*5+X*1)-0.8*(X-0.2))+torch.cos((Y-X)-0.4*(X)))*(R<R_probe) #(torch.sqrt(3*X**2+1.5*Y**2)+torch.pi/3)#*(torch.exp(-0.1*R)) #np.mod(0.1*(torch.sin(150*R)+torch.cos((Y*10+X*30)**2-0.8*(X*75-0.2))+torch.cos((Y*10-X*33)**2-0.4*(X*50-0.2))),1)
Diffuser = torch.zeros_like(R)
Diffuser = torch.randn_like(R)*(R<R_probe)
P_test = torch.zeros_like(R)
P_test = torch.exp(2j*np.pi*Diffuser)*(R<R_probe)#*(torch.exp(-0.8*R))
initial_probe_amplitude = P_test


def normalise_probe_from_data(I_meas_normalized, initial_probe_amplitude):
    # 1. Average the data and take the square root
    I_avg = torch.mean(I_meas_normalized, dim=(0, 1)) # Average over pol states and scan positions

    I_w_initial_p = (torch.abs(F(initial_probe_amplitude))**2)
    scaler = torch.sqrt(torch.sum(I_avg) / (torch.sum(I_w_initial_p) + 1e-8))
    print('Probe scaler:', scaler)
    return initial_probe_amplitude*scaler

#initial_probe_amplitude = normalise_probe_from_data(I_sim_norm, initial_probe_amplitude)
#print('Max of detector with initial probe:', torch.max(torch.abs(F(initial_probe_amplitude))**2))
#print('Max of normalized detector data:', torch.max(I_sim_norm))

optimizer_params={'l_lr': 1e-1, 'CA_lr': 1e-5, 'probe_lr':1e-1}
loss_prefactors={'sqrt_amp_pf': 0.0, 'gradient_pf': 1e-4, 
                 'anisotropy_pf': 0.0, 'probe_localisation_pf':0.0,
                 'STXM_pf': 1.0} # Different parts of the Loss have different weights

'''Randomisation can help a minimum be found - this section tells what gets randomised, by how much and when it stops taking effect'''
object_randomisation = False # Randomise the object at the start of the optimization to help escape local minima
probe_randomisation = False # Randomise the probe at the start of the optimization to help escape local minima
randomisation_dict = {'object_randomisation': object_randomisation, 'probe_randomisation': probe_randomisation,
                      'object_rand_pf': 0.15, 'probe_rand_pf': 0.1, 'iter_spacing': 5, 'final_iteration': 50}

result = optimize_object_and_probe_with_scheduler(scan, pol_angles, I_sim, H, W,
                                   initial_probe_amplitude=initial_probe_amplitude,
                                   initial_l=initial_l,
                                   num_iterations=800, device=device, 
                                   loss_prefactors=loss_prefactors, object_randomisation=object_randomisation,
                                    probe_randomisation=probe_randomisation, optimizer_params=optimizer_params)
# Out:
# Calculated initial fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# [0.1, 0.1]
# Iter    0 | Loss = 2.078947e+08 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter    1 | Loss = 1.227499e+08 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter    2 | Loss = 7.377623e+07 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter    3 | Loss = 4.687151e+07 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter    4 | Loss = 3.184726e+07 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter    5 | Loss = 2.311833e+07 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter    6 | Loss = 1.785970e+07 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter    7 | Loss = 1.444782e+07 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter    8 | Loss = 1.197715e+07 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter    9 | Loss = 1.001284e+07 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter   10 | Loss = 8.377773e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter   11 | Loss = 7.006746e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter   12 | Loss = 5.870898e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter   13 | Loss = 4.947266e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter   14 | Loss = 4.209814e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter   15 | Loss = 3.628770e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter   16 | Loss = 3.172894e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter   17 | Loss = 2.812404e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter   18 | Loss = 2.521364e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter   19 | Loss = 2.279068e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# [0.1, 0.1]
# Iter   20 | Loss = 2.070323e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter   21 | Loss = 1.884964e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter   22 | Loss = 1.716882e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter   23 | Loss = 1.562892e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter   24 | Loss = 1.421632e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter   25 | Loss = 1.292603e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter   26 | Loss = 1.175470e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter   27 | Loss = 1.069682e+06 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter   28 | Loss = 9.743317e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter   29 | Loss = 8.882260e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter   30 | Loss = 8.101089e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter   31 | Loss = 7.388847e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter   32 | Loss = 6.737703e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter   33 | Loss = 6.143075e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter   34 | Loss = 5.602936e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter   35 | Loss = 5.116443e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter   36 | Loss = 4.682594e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter   37 | Loss = 4.299189e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter   38 | Loss = 3.962258e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter   39 | Loss = 3.666129e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# [0.1, 0.1]
# Iter   40 | Loss = 3.403944e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter   41 | Loss = 3.168458e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter   42 | Loss = 2.952948e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter   43 | Loss = 2.751951e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter   44 | Loss = 2.561761e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter   45 | Loss = 2.380570e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter   46 | Loss = 2.208250e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter   47 | Loss = 2.045874e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter   48 | Loss = 1.895061e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter   49 | Loss = 1.757322e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter   50 | Loss = 1.633513e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter   51 | Loss = 1.523533e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter   52 | Loss = 1.426289e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter   53 | Loss = 1.339937e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter   54 | Loss = 1.262263e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter   55 | Loss = 1.191128e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter   56 | Loss = 1.124819e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter   57 | Loss = 1.062250e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter   58 | Loss = 1.002978e+05 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free object parameters, fixing probe amplitude.
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# Iter   59 | Loss = 9.470491e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free probe, fixed object
# Calculated fluence from probe amplitude: 1.000000e+06, target fluence: 1.000000e+06
# [0.1, 0.1]
# Iter   60 | Loss = 8.947619e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free probe, fixed object
# Calculated fluence from probe amplitude: 1.002698e+06, target fluence: 1.000000e+06
# Iter   61 | Loss = 8.017398e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free probe, fixed object
# Calculated fluence from probe amplitude: 1.005512e+06, target fluence: 1.000000e+06
# Iter   62 | Loss = 7.337920e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free probe, fixed object
# Calculated fluence from probe amplitude: 1.008168e+06, target fluence: 1.000000e+06
# Iter   63 | Loss = 6.923148e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free probe, fixed object
# Calculated fluence from probe amplitude: 1.010234e+06, target fluence: 1.000000e+06
# Iter   64 | Loss = 6.702168e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free probe, fixed object
# Calculated fluence from probe amplitude: 1.011705e+06, target fluence: 1.000000e+06
# Iter   65 | Loss = 6.593230e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free probe, fixed object
# Calculated fluence from probe amplitude: 1.012686e+06, target fluence: 1.000000e+06
# Iter   66 | Loss = 6.545710e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free probe, fixed object
# Calculated fluence from probe amplitude: 1.013219e+06, target fluence: 1.000000e+06
# Iter   67 | Loss = 6.519386e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free probe, fixed object
# Calculated fluence from probe amplitude: 1.013349e+06, target fluence: 1.000000e+06
# Iter   68 | Loss = 6.493527e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free probe, fixed object
# Calculated fluence from probe amplitude: 1.013134e+06, target fluence: 1.000000e+06
# Iter   69 | Loss = 6.463491e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free probe, fixed object
# Calculated fluence from probe amplitude: 1.012642e+06, target fluence: 1.000000e+06
# Iter   70 | Loss = 6.434865e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free probe, fixed object
# Calculated fluence from probe amplitude: 1.011959e+06, target fluence: 1.000000e+06
# Iter   71 | Loss = 6.417542e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free probe, fixed object
# Calculated fluence from probe amplitude: 1.011179e+06, target fluence: 1.000000e+06
# Iter   72 | Loss = 6.418916e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free probe, fixed object
# Calculated fluence from probe amplitude: 1.010406e+06, target fluence: 1.000000e+06
# Iter   73 | Loss = 6.439452e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free probe, fixed object
# Calculated fluence from probe amplitude: 1.009737e+06, target fluence: 1.000000e+06
# Iter   74 | Loss = 6.471156e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free probe, fixed object
# Calculated fluence from probe amplitude: 1.009245e+06, target fluence: 1.000000e+06
# Iter   75 | Loss = 6.500600e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free probe, fixed object
# Calculated fluence from probe amplitude: 1.008972e+06, target fluence: 1.000000e+06
# Iter   76 | Loss = 6.514905e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free probe, fixed object
# Calculated fluence from probe amplitude: 1.008927e+06, target fluence: 1.000000e+06
# Iter   77 | Loss = 6.506891e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free probe, fixed object
# Calculated fluence from probe amplitude: 1.009089e+06, target fluence: 1.000000e+06
# Iter   78 | Loss = 6.476750e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free probe, fixed object
# Calculated fluence from probe amplitude: 1.009419e+06, target fluence: 1.000000e+06
# Iter   79 | Loss = 6.430546e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free probe, fixed object
# Calculated fluence from probe amplitude: 1.009863e+06, target fluence: 1.000000e+06
# [0.1, 0.1]
# Iter   80 | Loss = 6.377048e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free probe, fixed object
# Calculated fluence from probe amplitude: 1.010361e+06, target fluence: 1.000000e+06
# Iter   81 | Loss = 6.324413e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free probe, fixed object
# Calculated fluence from probe amplitude: 1.010856e+06, target fluence: 1.000000e+06
# Iter   82 | Loss = 6.278131e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free probe, fixed object
# Calculated fluence from probe amplitude: 1.011295e+06, target fluence: 1.000000e+06
# Iter   83 | Loss = 6.240229e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free probe, fixed object
# Calculated fluence from probe amplitude: 1.011638e+06, target fluence: 1.000000e+06
# Iter   84 | Loss = 6.210029e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free probe, fixed object
# Calculated fluence from probe amplitude: 1.011860e+06, target fluence: 1.000000e+06
# Iter   85 | Loss = 6.185507e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free probe, fixed object
# Calculated fluence from probe amplitude: 1.011952e+06, target fluence: 1.000000e+06
# Iter   86 | Loss = 6.164756e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free probe, fixed object
# Calculated fluence from probe amplitude: 1.011921e+06, target fluence: 1.000000e+06
# Iter   87 | Loss = 6.146829e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free probe, fixed object
# Calculated fluence from probe amplitude: 1.011787e+06, target fluence: 1.000000e+06
# Iter   88 | Loss = 6.131822e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free probe, fixed object
# Calculated fluence from probe amplitude: 1.011579e+06, target fluence: 1.000000e+06
# Iter   89 | Loss = 6.120316e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free probe, fixed object
# Calculated fluence from probe amplitude: 1.011335e+06, target fluence: 1.000000e+06
# Iter   90 | Loss = 6.112376e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free probe, fixed object
# Calculated fluence from probe amplitude: 1.011091e+06, target fluence: 1.000000e+06
# Iter   91 | Loss = 6.107073e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free probe, fixed object
# Calculated fluence from probe amplitude: 1.010880e+06, target fluence: 1.000000e+06
# Iter   92 | Loss = 6.102370e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free probe, fixed object
# Calculated fluence from probe amplitude: 1.010729e+06, target fluence: 1.000000e+06
# Iter   93 | Loss = 6.095850e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free probe, fixed object
# Calculated fluence from probe amplitude: 1.010652e+06, target fluence: 1.000000e+06
# Iter   94 | Loss = 6.085500e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free probe, fixed object
# Calculated fluence from probe amplitude: 1.010655e+06, target fluence: 1.000000e+06
# Iter   95 | Loss = 6.070372e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free probe, fixed object
# Calculated fluence from probe amplitude: 1.010732e+06, target fluence: 1.000000e+06
# Iter   96 | Loss = 6.050793e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free probe, fixed object
# Calculated fluence from probe amplitude: 1.010867e+06, target fluence: 1.000000e+06
# Iter   97 | Loss = 6.028111e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free probe, fixed object
# Calculated fluence from probe amplitude: 1.011039e+06, target fluence: 1.000000e+06
# Iter   98 | Loss = 6.004089e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Free probe, fixed object
# Calculated fluence from probe amplitude: 1.011223e+06, target fluence: 1.000000e+06
# Iter   99 | Loss = 5.980397e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Optimizing all parameters.
# Calculated fluence from probe amplitude: 1.011395e+06, target fluence: 1.000000e+06
# [0.1, 0.1]
# Iter  100 | Loss = 5.958113e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Optimizing all parameters.
# Calculated fluence from probe amplitude: 1.011532e+06, target fluence: 1.000000e+06
# Iter  101 | Loss = 5.619720e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Optimizing all parameters.
# Calculated fluence from probe amplitude: 1.011574e+06, target fluence: 1.000000e+06
# Iter  102 | Loss = 5.267146e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Optimizing all parameters.
# Calculated fluence from probe amplitude: 1.011508e+06, target fluence: 1.000000e+06
# Iter  103 | Loss = 4.906640e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Optimizing all parameters.
# Calculated fluence from probe amplitude: 1.011363e+06, target fluence: 1.000000e+06
# Iter  104 | Loss = 4.553307e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Optimizing all parameters.
# Calculated fluence from probe amplitude: 1.011204e+06, target fluence: 1.000000e+06
# Iter  105 | Loss = 4.224085e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Optimizing all parameters.
# Calculated fluence from probe amplitude: 1.011108e+06, target fluence: 1.000000e+06
# Iter  106 | Loss = 3.929184e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Optimizing all parameters.
# Calculated fluence from probe amplitude: 1.011145e+06, target fluence: 1.000000e+06
# Iter  107 | Loss = 3.668184e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Optimizing all parameters.
# Calculated fluence from probe amplitude: 1.011367e+06, target fluence: 1.000000e+06
# Iter  108 | Loss = 3.433117e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Optimizing all parameters.
# Calculated fluence from probe amplitude: 1.011791e+06, target fluence: 1.000000e+06
# Iter  109 | Loss = 3.215219e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Optimizing all parameters.
# Calculated fluence from probe amplitude: 1.012406e+06, target fluence: 1.000000e+06
# Iter  110 | Loss = 3.010509e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Optimizing all parameters.
# Calculated fluence from probe amplitude: 1.013165e+06, target fluence: 1.000000e+06
# Iter  111 | Loss = 2.821223e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Optimizing all parameters.
# Calculated fluence from probe amplitude: 1.014004e+06, target fluence: 1.000000e+06
# Iter  112 | Loss = 2.653056e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Optimizing all parameters.
# Calculated fluence from probe amplitude: 1.014842e+06, target fluence: 1.000000e+06
# Iter  113 | Loss = 2.510479e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Optimizing all parameters.
# Calculated fluence from probe amplitude: 1.015594e+06, target fluence: 1.000000e+06
# Iter  114 | Loss = 2.393193e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j
# Optimizing all parameters.
# Calculated fluence from probe amplitude: 1.016186e+06, target fluence: 1.000000e+06
# Iter  115 | Loss = 2.295658e+04 | C, A1, A2: 5.000000e+01+5.000000e+00j, 1.000000e+00+3.000000e+02j, 5.000000e+00+2.000000e+00j

# %% [markdown]
# ## Loop through a few different hyperparameters

# %%
import itertools
import pickle
import os

# Initial probe and object
initial_theta = torch.nn.Parameter(torch.rand((H, W), device=device) * 0.01 + torch.pi/2)
initial_phi   = torch.nn.Parameter(torch.rand((H, W), device=device) * 0.1 + torch.pi/2)

P_test = torch.zeros_like(R)
Diffuser = torch.rand((H, W), device=device)
P_test = torch.exp(2j*np.pi*Diffuser)*(torch.exp(-0.8*R))
initial_probe_amplitude = P_test


# --- hyperparameter ranges ---
gradient_pf_list = [1.0, 1e-1, 1e-1]
anisotropy_pf_list = [1.0, 1e-1, 1e-1]

base_loss_prefactors = {
    'sqrt_amp_pf': 1.0,
}

optimizer_params = {
    'theta_lr': 5e-1,
    'phi_lr': 5e-1,
    'CA_lr': 1e-5,
    'probe_lr': 60e-1
}

output_dir = "hyperparam_runs"
os.makedirs(output_dir, exist_ok=True)

# --- loop ---
for gradient_pf, anisotropy_pf in itertools.product(gradient_pf_list, anisotropy_pf_list):
    
    loss_prefactors = {
        **base_loss_prefactors,
        'gradient_pf': gradient_pf,
        'anisotropy_pf': anisotropy_pf
    }
    
    run_name = f"grad_{gradient_pf:.0e}_anis_{anisotropy_pf:.0e}"
    
    plot_filename = os.path.join(output_dir, f"plot_{run_name}.png")
    pickle_filename = os.path.join(output_dir, f"result_{run_name}.pkl")
    
    print(f"Running: {run_name}")
    
    result = optimize_object_and_probe_with_scheduler(
        scan, pol_angles, I_sim, H, W,
        initial_theta=initial_theta,
        initial_phi=initial_phi,
        initial_probe_amplitude=initial_probe_amplitude,
        num_iterations=80,
        device=device,
        loss_prefactors=loss_prefactors,
        plot_filename=plot_filename
    )
    
    # optional: include params explicitly in saved object
    result_to_save = {
        "run_name": run_name,
        "gradient_pf": gradient_pf,
        "anisotropy_pf": anisotropy_pf,
        "result": result
    }
    
    # save immediately
    with open(pickle_filename, "wb") as f:
        pickle.dump(result_to_save, f)

    print(f"Saved: {pickle_filename}")

# %%
import os
import pickle
import glob
import matplotlib.pyplot as plt

results_dir = "hyperparam_runs"

# find all pickle files
pickle_files = sorted(glob.glob(os.path.join(results_dir, "result_*.pkl")))

plt.figure()

for pf in pickle_files:
    with open(pf, "rb") as f:
        data = pickle.load(f)
    
    run_name = data["run_name"]
    loss_history = data["result"]["loss_history"]
    
    plt.plot(loss_history, label=run_name)

plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.yscale("log")
plt.title("Loss history for different hyperparameters")

# optional: legend can get crowded
plt.legend(fontsize=8)
plt.tight_layout()
plt.show()

# %%
plot_probe_maps(result["probe_amplitude"].detach().cpu().numpy(), Lx, Ly)
plot_theta_phi_maps(
    result["theta"].detach().cpu().numpy(),
    result["phi"].detach().cpu().numpy(),
    Lx,
    Ly,
    theta_cmap='magma',
    phi_cmap=RGB_scale,
    label_axes=True,
)

# %%
plt.plot(result["loss_history"])
plt.ylabel('Loss')
plt.xlabel('Iteration')
plt.yscale('log')
plt.show()
